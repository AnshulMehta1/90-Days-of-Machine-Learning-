# %%
# Importing the Necessary Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import networkx as nx
import os
import json
import matplotlib.pyplot as plt
import networkx as nx

# %%
# Installing PyGithub
# !pip install pygithub
# Out:
# Requirement already satisfied: pygithub in /usr/local/lib/python3.7/dist-packages (1.55)
# Requirement already satisfied: deprecated in /usr/local/lib/python3.7/dist-packages (from pygithub) (1.2.13)
# Requirement already satisfied: pyjwt>=2.0 in /usr/local/lib/python3.7/dist-packages (from pygithub) (2.3.0)
# Requirement already satisfied: pynacl>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from pygithub) (1.5.0)
# Requirement already satisfied: requests>=2.14.0 in /usr/local/lib/python3.7/dist-packages (from pygithub) (2.23.0)
# Requirement already satisfied: cffi>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from pynacl>=1.4.0->pygithub) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.4.1->pynacl>=1.4.0->pygithub) (2.21)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.14.0->pygithub) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.14.0->pygithub) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.14.0->pygithub) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.14.0->pygithub) (1.24.3)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.7/dist-packages (from deprecated->pygithub) (1.14.0)

# %%
# Setting up the API Pygithub
# PAT and Access Key
from github import Github
g = Github("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")
ACCESS_TOKEN = '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'
client = Github(ACCESS_TOKEN, per_page=200)

# %%
# Entering the Name of a Popular User
USER = 'yashrajkakkad'
user = client.get_user(USER)

# %%
# Getting the List of Followers
import networkx as nx
# Graph of Followers
g_followers = nx.Graph()
# List of followers
g_followers.add_node(user.login , type='user')

followers = [ s for s in user.get_followers() ]
print ("Number of followers", len(followers))
for follower in followers:
    g_followers.add_node(follower.login + '(user)', type='user')
    g_followers.add_edge(follower.login + '(user)', user.login + '(repo)', type='follows')
# %matplotlib inline
# import matplotlib.pyplot as plt
# plt.figure(figsize=(15,10))
# nx.draw(g_followers, with_labels=True, node_size=1)
# plt.show()
# Out:
# Number of followers 144

# %%
followers
# Out:
# [NamedUser(login="Magicianred"),
#  NamedUser(login="amitntrivedi"),
#  NamedUser(login="cryebiggie"),
#  NamedUser(login="hetp111"),
#  NamedUser(login="shaykhullinsergey"),
#  NamedUser(login="AtivJoshi"),
#  NamedUser(login="pranshukharkwal"),
#  NamedUser(login="15pratik"),
#  NamedUser(login="kushsharma1001"),
#  NamedUser(login="parshwa1999"),
#  NamedUser(login="raj1238"),
#  NamedUser(login="samkitk"),
#  NamedUser(login="Harshiv07"),
#  NamedUser(login="aayuvraj"),
#  NamedUser(login="timusp"),
#  NamedUser(login="nikhilbalwani"),
#  NamedUser(login="Meet-Modi"),
#  NamedUser(login="tirthjivani"),
#  NamedUser(login="twistloop"),
#  NamedUser(login="realharshbhatt"),
#  NamedUser(login="manav2401"),
#  NamedUser(login="charmilgandhi"),
#  NamedUser(login="amanmdave"),
#  NamedUser(login="Teju-g49"),
#  NamedUser(login="qusaionali"),
#  NamedUser(login="smv1999"),
#  NamedUser(login="dhruvildave"),
#  NamedUser(login="princedalsaniya"),
#  NamedUser(login="Mithilesh1609"),
#  NamedUser(login="MRJ35"),
#  NamedUser(login="AdityaBirangal"),
#  NamedUser(login="sakshi006"),
#  NamedUser(login="yash982000"),
#  NamedUser(login="shreyanshdeep"),
#  NamedUser(login="PrayagS"),
#  NamedUser(login="harvishj"),
#  NamedUser(login="lilujunai"),
#  NamedUser(login="adityabhandari15"),
#  NamedUser(login="rhutikcodes"),
#  NamedUser(login="harsh760"),
#  NamedUser(login="anusandesara"),
#  NamedUser(login="dhatrikapuriya"),
#  NamedUser(login="NamitS27"),
#  NamedUser(login="jimil749"),
#  NamedUser(login="D3VAR5H"),
#  NamedUser(login="nisarg14"),
#  NamedUser(login="Param-Raval"),
#  NamedUser(login="mrparth23"),
#  NamedUser(login="kairavkkp"),
#  NamedUser(login="jainam2907"),
#  NamedUser(login="mrindani"),
#  NamedUser(login="RidhamShah"),
#  NamedUser(login="mrchocha"),
#  NamedUser(login="JeetKaria06"),
#  NamedUser(login="Sharvil24600"),
#  NamedUser(login="Kaushal1011"),
#  NamedUser(login="arpitvaghela"),
#  NamedUser(login="MuskanM1"),
#  NamedUser(login="YashilDepani"),
#  NamedUser(login="shahshaswat2"),
#  NamedUser(login="kh-2000"),
#  NamedUser(login="ankitgoyal0301"),
#  NamedUser(login="caped-crusader16"),
#  NamedUser(login="pracheejaviya1"),
#  NamedUser(login="abhijeetaman007"),
#  NamedUser(login="parthpatel1470"),
#  NamedUser(login="parth-27"),
#  NamedUser(login="harshilmehta67"),
#  NamedUser(login="MayankkumarTank"),
#  NamedUser(login="UditKapadia"),
#  NamedUser(login="DipikaPawar12"),
#  NamedUser(login="ratnam18"),
#  NamedUser(login="devshree07"),
#  NamedUser(login="khushboogupta13"),
#  NamedUser(login="meetakbari"),
#  NamedUser(login="Hirmay"),
#  NamedUser(login="shreyashpanchal"),
#  NamedUser(login="jds311"),
#  NamedUser(login="Priyank31"),
#  NamedUser(login="Pirateking289"),
#  NamedUser(login="vinaykakkad"),
#  NamedUser(login="Devam911"),
#  NamedUser(login="Harsh1925"),
#  NamedUser(login="SuhaneeP"),
#  NamedUser(login="Sameep1234"),
#  NamedUser(login="foram-s1"),
#  NamedUser(login="Poojan987"),
#  NamedUser(login="kashishjivani"),
#  NamedUser(login="parthmshah1302"),
#  NamedUser(login="VidishJoshi"),
#  NamedUser(login="aayush1607"),
#  NamedUser(login="RP-72"),
#  NamedUser(login="jaskaran-23"),
#  NamedUser(login="neelpopat242"),
#  NamedUser(login="dhruv-vachhani"),
#  NamedUser(login="jaympatel481"),
#  NamedUser(login="Darshan-upadhyay1110"),
#  NamedUser(login="Harshpatel2222"),
#  NamedUser(login="KAVAN-DESAI"),
#  NamedUser(login="dc-exe"),
#  NamedUser(login="tirthPatel177"),
#  NamedUser(login="joshi-omkar"),
#  NamedUser(login="utkarshluthra"),
#  NamedUser(login="DhruvPrajapati4"),
#  NamedUser(login="bhavya-tech"),
#  NamedUser(login="pateljay15"),
#  NamedUser(login="nancyradadia"),
#  NamedUser(login="hardi15"),
#  NamedUser(login="akshayke"),
#  NamedUser(login="Mananshi"),
#  NamedUser(login="YugamsinhChavda"),
#  NamedUser(login="meghnakanade"),
#  NamedUser(login="dineshssdn-867"),
#  NamedUser(login="Jimmy290901"),
#  NamedUser(login="neversettlejay"),
#  NamedUser(login="PClub-Ahmedabad-University"),
#  NamedUser(login="Hrutika26"),
#  NamedUser(login="tirth8205"),
#  NamedUser(login="VishwaRaval"),
#  NamedUser(login="paramjani12"),
#  NamedUser(login="Vidhu007"),
#  NamedUser(login="nipun3333"),
#  NamedUser(login="Prathamesh-Shanbhag"),
#  NamedUser(login="jinesh0109"),
#  NamedUser(login="taha-yasin"),
#  NamedUser(login="zaverisanya"),
#  NamedUser(login="Nisargpatel16"),
#  NamedUser(login="kavania2002"),
#  NamedUser(login="vintwelve"),
#  NamedUser(login="jevinjivani2507"),
#  NamedUser(login="AkshilVT"),
#  NamedUser(login="vatsal-dp"),
#  NamedUser(login="Samarth1302"),
#  NamedUser(login="ashman119"),
#  NamedUser(login="priyanshu-28"),
#  NamedUser(login="contactsmriti"),
#  NamedUser(login="Aagam-13"),
#  NamedUser(login="Narendra99599"),
#  NamedUser(login="sharmavats"),
#  NamedUser(login="heet9201"),
#  NamedUser(login="NyctophileOtaku"),
#  NamedUser(login="MeetSojitra"),
#  NamedUser(login="Maulik176"),
#  NamedUser(login="Aditya-Bhate")]

# %%
# # followers
# # Cleaning the Data
# followers_name=[]
# for f in followers:
#   # print(f.name)
#   followers_name.append(f.name)

# %%
followers_name=pd.read_csv('/content/user_list.csv')

# %%
len(followers_name)
# Out:
# 4892

# %%
users_df=pd.DataFrame(followers_name)

# %%
users_df.to_csv('user_list.csv',index=False)

# %% [markdown]
# Two Loops <br>
# One for User <br>
# Get all the Repos for a User<br>
# Dictionary - User and Keywords of Repos<br>
# Add the names of all the keywords in a single String<br>
# Use a 2D List for that and each List is a List of Topics for a Patricular User

# %%
# Checking the  List  of the Followers
# Retreiving the Information of the Top 10 Repositories for each Follower
r = user.get_repos()
r

# %%
UserList=[]
TwodList=[]
for u in followers:
  UserList.append(u.name)
  repo=u.get_repos()
  userRepoList=[]
  # For Lopp for getting the Keywords of Repo
  for r in repo:
    # Add a try catch here to avoid errors
    try:
      userRepoList.append(str(r.name))
      userRepoList.append(str(r.description))
      userRepoList.append(str(r.language))
      # userRepoList.append(r.get_topics())
    except:
      continue
  TwodList.append(userRepoList)

# %%
TwodList
# Out:
# [['.github',
#   'None',
#   'None',
#   '.NET-Core-Business-Layer',
#   'a .net core project with business architecture (Northwind DB)',
#   'None',
#   '.NET-CORE-MediatR',
#   '.NET CORE & MediatR & CQRS',
#   'None',
#   '.NET-design-patterns',
#   'Design patterns implemented in .NET Core',
#   'None',
#   '30-Days-Of-JavaScript',
#   '30 days of JavaScript programming challenge is a step by step guide to learn JavaScript programming language in 30 days. This challenge may take up to 100 days,  please just follow your own pace. ',
#   'None',
#   '30-Days-Of-Python',
#   '30 days of Python programming challenge is a step by step guide to learn the Python programming language in 30 days. This challenge may take up to 100 days, follow your own pace. ',
#   'None',
#   '30-Days-Of-React',
#   '30 Days of  React challenge is a step by step guide to learn React in 30 days. It requires HTML, CSS, and JavaScript knowledge. You should be comfortable with JavaScript before you start to React.  If you are not comfortable with JavaScript check out 30DaysOfJavaScript. This is a continuation of 30 Days Of JS.  This challenge may take up to 100 days, follow your own pace. ',
#   'None',
#   '3_Tier_Banking_Application',
#   'A 3 tier banking application developed in C# .net',
#   'None',
#   '50projects50days',
#   '50+ mini web projects using HTML, CSS & JS',
#   'None',
#   '51-days_51-FrontEnd-submits',
#   '51 little to medium size HTML, CSS & JS projects',
#   'None',
#   '90swithSass',
#   "Practical usage of Sass on making websites with a 90's style.",
#   'None',
#   'ABC',
#   "ABC - Ace Book Club was a project for Start2impact where I had used React.js - It's a website where you can search in a large collection of books",
#   'None',
#   'abot',
#   'Cross Platform C# web crawler framework built for speed and flexibility. Please star this project! +1.',
#   'None',
#   'abp',
#   'Open Source Web Application Framework for ASP.NET Core',
#   'None',
#   'accesses_statistics_system',
#   'A simple web accesses statistics system',
#   'None',
#   'acorn',
#   'A small, fast, JavaScript-based JavaScript parser',
#   'None',
#   'acorn-jsx',
#   'Alternative, faster React.js JSX parser',
#   'None',
#   'activeadmin',
#   'The administration framework for Ruby on Rails applications.',
#   'None',
#   'advancedCSS',
#   'Projects made during the Advanced CSS and SASS course (held by Jonas Schmedtmann)',
#   'None',
#   'af-aligner',
#   'LF Aligner helps translators create translation memories from texts and their translations. It relies on Hunalign for automatic sentence pairing. Input: txt, doc, docx, rtf, pdf, html. Output: tab delimited txt, TMX and xls. With web features.',
#   'None',
#   'airform',
#   'Functional HTML forms for Front-End Developers.',
#   'None',
#   'Aksara4',
#   "Aksara is a powerful framework engine to realize what's only in your dreams becomes something real. Serving both CMS or Framework, produce both HEADLESS or TRADITIONAL output just by writing in single controller. Yet it's reusable, scalable and ready to use!",
#   'None',
#   'all-shields-cli',
#   '🦌 Tool to help automate your badges from dotfiles for your markdown. ',
#   'TypeScript',
#   'aluraquiz-booksquiz',
#   'Projeto da Imersão React com NextJS da Alura',
#   'None',
#   'alyra-custom-wp-block-our-sponsors',
#   'None',
#   'None',
#   'alyra-intro-dom',
#   'None',
#   'None',
#   'alyra-weather-app-start',
#   'None',
#   'None',
#   'angepili',
#   'None',
#   'None',
#   'angepili.github.io',
#   'None',
#   'HTML',
#   'AngleSharp',
#   ':angel: The ultimate angle brackets parser library parsing HTML5, MathML, SVG and CSS to construct a DOM based on the official W3C specifications.',
#   'None',
#   'Angular-API-Project',
#   'None',
#   'None',
#   'angular-first-project',
#   'App to learn the core concepts of Angular',
#   'None',
#   'angular-frontend-app',
#   'Manage Persons provided by a Backend App - Angular app related to "SpringBoot-Angular-confinement" app',
#   'None',
#   'angular-storeapp',
#   'Examples for angular',
#   'None',
#   'Angularization',
#   'A complete guide to getting started with visual test-driven, component-driven Angular development with Storybook. (Work-in-progress)',
#   'None',
#   'angularShop',
#   'None',
#   'None',
#   'AngularTdd',
#   'AngularTdd',
#   'None',
#   'Angular_Examples',
#   'Some test of Angular Framework',
#   'Gherkin',
#   'anonymous-mailer',
#   'Anonymous E-mail sending script using PHP mail function',
#   'None',
#   'ant-design',
#   '🌈  A UI Design Language and React UI library',
#   'None',
#   'AOs',
#   'AOs is a terminal based Operating System inspired by MS-DOS and BatchUnited Terminal Operating System.',
#   'None',
#   'AP-Midterm-Project-Spring-2021',
#   'Simple implementation of Mafia (Werewolf) game',
#   'None',
#   'AP-Spring-2021-HW4-UNO-CardGame',
#   'UNO card game implementation',
#   'None',
#   'AP-Spring2021-HW2-Internet-Banking-System',
#   'An implementation of a comprehensive internet banking system.',
#   'None',
#   'AP-Spring2021-HW3-OnlineGroceryStore',
#   'An implementation of an online grocery store.',
#   'None',
#   'API-coffee',
#   'Criando uma API com NodeJs ',
#   'None',
#   'apiato',
#   "PHP Framework for building scalable API's on top of Laravel.",
#   'None',
#   'apidotnet-mongodb',
#   'Projeto de uma API.NET integrada ao MongoDB. Repositório referente a estudos do bootcamp Avanade Fullstack Developer (.NET + Angular).',
#   'None',
#   'APIs-CRUD-NodeJs',
#   'A set of simple APIs built with NodeJs',
#   'None',
#   'apostrophe',
#   'ApostropheCMS is a full-featured, open-source CMS built with Node.js that seeks to empower organizations by combining in-context editing and headless architecture in a full-stack JS environment.',
#   'None',
#   'app-ideas',
#   'A Collection of application ideas which can be used to improve your coding skills.',
#   'None',
#   'AppLibraryReact',
#   'None',
#   'None',
#   'appschedweb',
#   'None',
#   'None',
#   'apresentacao-perfil-github',
#   'Website usando a API do GitHub para visualização de repositórios e dados de um usuário',
#   'None',
#   'aqualink-app',
#   'Aqualink.org Ocean Monitoring Application',
#   'None',
#   'arcadeClassics',
#   'Retro game recreations',
#   'None',
#   'ArcaeaModder',
#   'None',
#   'None',
#   'Architecture',
#   'Architecture .NET 5, ASP.NET Core 5, Entity Framework Core 5, C# 9, Angular 11, Clean Code, SOLID, DDD.',
#   'None',
#   'architecture-template',
#   'Solution with template of Architecture that I have been using in my projects',
#   'None',
#   'ArchUnit',
#   'A Java architecture test library, to specify and assert architecture rules in plain Java',
#   'None',
#   'ArchUnitNET',
#   'A C# architecture test library to specify and assert architecture rules in C# for automated testing.',
#   'None',
#   'ArgsParser',
#   'A command line arguments parser in .NET Core',
#   'None',
#   'Art-Arch',
#   'It is a website where you can see artistic buildings called Art & Arch with React Js',
#   'None',
#   'asp-net-core-web-api_clientes',
#   'Web API for the management of customer information.',
#   'None',
#   'Asp.Net-Core-5.0-Web-API-CRUD-with-Angular-11',
#   'Asp.Net Core 5.0 Web API CRUD with Angular 11',
#   'None',
#   'ASP.NET-Core-MVC-without-Enitity-Framework',
#   'ASP.NET Core MVC without Enitity Framework',
#   'None',
#   'ASP.NET-Core-Template',
#   'A ready-to-use template for ASP.NET Core with repositories, services, models mapping, DI and StyleCop warnings fixed.',
#   'None',
#   'ASP.NET-IntegrationTests-Issue',
#   'None',
#   'None',
#   'ASP.NET-Server-Architectures',
#   'None',
#   'None',
#   'Asp.NetCoreToDoList',
#   'None',
#   'None',
#   'aspnet-5-ef-core-5-aspnet-identity-blog',
#   'None',
#   'None',
#   'aspnet-core-identity',
#   'ASP.NET Core Identity Series',
#   'None',
#   'aspnet-core-mvc',
#   'Asp.Net Core MVC 3.1 tutorial with Live application | Nitish',
#   'None',
#   'AspNet.Mvc.TypedRouting',
#   'A collection of extension methods providing strongly typed routing and link generation for ASP.NET Core MVC projects.',
#   'None',
#   'aspnet5-angular2-typescript',
#   'Cross-platform Single Page Applications with ASP.NET Core, Angular 4 & TypeScript',
#   'None',
#   'aspnetcore-effective-logging',
#   'None',
#   'None',
#   'aspnetcore-json-rpc',
#   'JSON-RPC 2.0 middleware for ASP.NET Core in .NET 5',
#   'None',
#   'aspnetcore-recipes',
#   'None',
#   'None',
#   'AspNetCore.Docs',
#   'Documentation for ASP.NET Core',
#   'None',
#   'AspNetCore.LightweightApi',
#   'A lightweight & performant framework for APIs (endpoints), built on top ASP.NET Core (boilerplate)',
#   'None',
#   'AspNetCore.Mvc.HttpActionResults',
#   'A collection of HTTP status code action results and controller extension methods for ASP.NET Core MVC projects.',
#   'None',
#   'AspNetCore2API',
#   'ASP.NET Core 2 API, JWS (Json Web Token), Template',
#   'None',
#   'AspNetCoreFunctionalTestsIssueWithMvc',
#   'Proving an issue with Functional testing when the endpoints map to controllers',
#   'None',
#   'AspNetCoreMultipleProject',
#   'ASP.NET Core API EF Core and Swagger',
#   'None',
#   'AspNetCoreOData',
#   'ASP.NET Core OData: A server library built upon ODataLib and ASP.NET Core',
#   'None',
#   'AspNetCore_Examples',
#   'A repo for some test AspNetCore',
#   'None',
#   'AspNetExample',
#   'None',
#   'None',
#   'aspnetmvc-simple-app',
#   'a simple app in asp.net mvc 4.7',
#   'CSS',
#   'AspNetMvcEg',
#   'An ASP.NET MVC eg. ([for] "example") and POC (proof-of-concept) web app ',
#   'None',
#   'AspNet_Examples',
#   'Some examples in AspNet ',
#   'None',
#   'Assembly',
#   'Project to study Assembly',
#   'None',
#   'assembly-tasm',
#   'sharing some assembly codes that I wrote (TASM syntax) with explanations',
#   'None',
#   'Aura-Operating-System',
#   'AuraOS, the Franco-English Operating System developed in C# using Cosmos!',
#   'None',
#   'aurora-api',
#   'Desenvolvendo sua aplicação com C# usando DDD_Digital Innovation One',
#   'None',
#   'aurora-api-project',
#   'Aurora is a project developed in .NET Core, where it aims to show how to create something using an architecture, in layers, simple and approaching, in a simplistic way, some concepts such as DDD.',
#   'None',
#   'automerge',
#   'A JSON-like data structure (a CRDT) that can be modified concurrently by different users, and merged again automatically.',
#   'None',
#   'Awesome-CMS-Core',
#   'Awesome CMS Core is an open source CMS built using ASP.Net Core & ReactJS with module seperation concern in mind and provide lastest trend of technology like .Net Core, React, Webpack, SASS, Background Job, Message Queue.',
#   'None',
#   'awesome-dotnet',
#   'A collection of awesome .NET libraries, tools, frameworks and software',
#   'None',
#   'awesome-dotnet-core',
#   ':honeybee: A collection of awesome .NET core libraries, tools, frameworks and software',
#   'None',
#   'awesome-dotnet-core-applications',
#   'An awesome collection of .NET Core real time, sample, architecture reference application projects',
#   'None',
#   'awesome-dotnet-core-education',
#   'A curated list of awesome articles and resources for learning and practicing about .Net Core and its related technologies.',
#   'None',
#   'awesome-flutter',
#   'An awesome list that curates the best Flutter libraries, tools, tutorials, articles and more.',
#   'None',
#   'awesome-italia',
#   'The organized list of awesome @italia projects',
#   'None',
#   'awesome-playwright',
#   'A curated list of awesome tools, utils and projects using Playwright',
#   'None',
#   'awps',
#   'A Modern WordPress Starter Theme for savvy Developers',
#   'None',
#   'axios',
#   'Promise based HTTP client for the browser and node.js',
#   'None',
#   'babel',
#   '🐠 Babel is a compiler for writing next generation JavaScript.',
#   'None',
#   'Backend',
#   'None',
#   'None',
#   'backend-recipe-app',
#   'A node backend infrastructure for a recipe app',
#   'None',
#   'badges',
#   ':pencil: Markdown code for lots of small badges :ribbon: :pushpin: (shields.io, forthebadge.com etc) :sunglasses:. Contributions are welcome! Please add yours!',
#   'None',
#   'banana-i18n',
#   'banana-i18n - Javascript Internationalization library',
#   'None',
#   'bank-api',
#   'Tecnologies: Typescript, Node, Express, MongoDB, Jest',
#   'None',
#   'bank-front',
#   'None',
#   'None',
#   'BarberShop',
#   'https://oxica.github.io/BarberShop/',
#   'None',
#   'barcodelib',
#   'C# Barcode Image Generation Library',
#   'None',
#   'base-webapi-accounts-network',
#   'A webapi with a basic framework who manage accounts and handler generic entities',
#   'C#',
#   'based.cooking',
#   'A simple culinary website.',
#   'None',
#   'basic-react-form',
#   'Basic form in React',
#   'None',
#   'BasicProje',
#   'BasicProje ',
#   'None',
#   'battleships',
#   'Battleships RESTful API',
#   'None',
#   'battleship_tech_test',
#   'None',
#   'None',
#   'bayeux',
#   'Historic Tale Construction Kit - opensource and customizable version !',
#   'None',
#   'BDD-TDD',
#   'test unitaire avec Jasmine, langage (Javascript)',
#   'None',
#   'BDD-toolkit-dotnet',
#   'Simple BDD syntax for writing domain model tests',
#   'None',
#   'BddDemo',
#   'None',
#   'None',
#   'Become-A-Full-Stack-Web-Developer',
#   'Free resources for learning Full Stack Web Development',
#   'None',
#   'BehaviorTrees',
#   'A Behavior Tree implementation based on C# events',
#   'None',
#   'benchdotnet-playground',
#   'None',
#   'None',
#   'Best-README-Template',
#   'An awesome README template to jumpstart your projects! ',
#   'None',
#   'BibleUtilities',
#   'Set of utilities to scan, parse, and work with Bible references.',
#   'None',
#   'BigliettOne',
#   'None',
#   'None',
#   'bitframework',
#   'Full stack dev framework for C# / TypeScript / JavaScript developers',
#   'None',
#   'blazor-starter',
#   'None',
#   'None',
#   'BlazorConcepts',
#   'None',
#   'None',
#   'BlazorFluentUI',
#   'Port of FluentUI/Office Fabric React components and style to Blazor',
#   'None',
#   'BlazorUnitTestingPrototype',
#   'None',
#   'None',
#   'BlazorWebAssemblySignalRAppv2',
#   'None',
#   'None',
#   'blobator',
#   'Utility which creates json/xml and image templates for blob tilesets (wang tiles with corners) written in C#. Also assembles tilesets from micro or subblobs.',
#   'None',
#   'block-scaffolding-wp',
#   'WordPress plugin template for extending Gutenberg',
#   'None',
#   'blog',
#   'Exemplo de um blog (front-end) feito com jQuery',
#   'None',
#   'blog-cqrs',
#   'A blog engine written in PHP and powered with CQRS + Event Sourcing',
#   'None',
#   'Blog-Pessoal',
#   '✔About me...',
#   'None',
#   'blog-post',
#   'None',
#   'None',
#   'Blog-Web-API',
#   'Blog Web Api',
#   'None',
#   'Blog-Website',
#   'Blog website design and codes using Master Page and ASP.NET.',
#   'None',
#   'BlogAPI',
#   'None',
#   'None',
#   'BlogAppUI',
#   'Blog Projesi UI Katmanı',
#   'None',
#   'BlogClient',
#   'Client Side of Blog Web Api',
#   'None',
#   'BlogPostsApi',
#   'BlogPostAPI project :: REST API C# ASP.NET Core',
#   'None',
#   'Blogs',
#   'REST API made in C# .NET CORE and SQL Server ',
#   'None',
#   'blogs-1',
#   'None',
#   'None',
#   'blog_app',
#   'Simple blog application created using Ruby on Rails',
#   'None',
#   'Blog_Pessoal',
#   'None',
#   'None',
#   'Bogus',
#   ':card_index: A simple and sane fake data generator for C#, F#, and VB.NET. Based on and ported from the famed faker.js.',
#   'None',
#   'boilerplate',
#   'MERN boilerplate ',
#   'None',
#   'bollette-server',
#   'Express server for my betting web app',
#   'None',
#   'bollette-ui',
#   'React UI for my betting web app',
#   'None',
#   'Book-App-Basic-Redux',
#   'Entry level redux book app',
#   'None',
#   'book-webapp',
#   'None',
#   'None',
#   'bookaround',
#   "Un'app per l'interscambio di libri - scolastici e non.",
#   'None',
#   'bookgame',
#   'None',
#   'None',
#   'BookStack',
#   'A platform to create documentation/wiki content built with PHP & Laravel',
#   'None',
#   'BookStore',
#   'None',
#   'None',
#   'Bookstore-1',
#   'None',
#   'None',
#   'bookstore-2',
#   'A complex C# - Windows Forms application using MySQL database',
#   'None',
#   'Boolbnb',
#   'Replica di un sito di appartamenti in affitto',
#   'None',
#   'boolDoctors',
#   'None',
#   'None',
#   'bootstrap-italia',
#   'Bootstrap Italia è un tema Bootstrap 4 conforme alle linee guida di design per i servizi web della PA',
#   'None',
#   'bootstrap-italia-playground',
#   'Bootstrap Italia Playground',
#   'None',
#   'bootstrap-web-components',
#   'Twitter Bootstrap as Web Components',
#   'None',
#   'boris-e-gattini',
#   'Citazioni di Boris e immagini di gattini.',
#   'None',
#   'BowlingGameCSharp',
#   'Tdd implementation in C# of the bowling game',
#   'None',
#   'breakingBadAPI',
#   'Projeto React utilizando breaking bad api',
#   'None',
#   'BubbleEngine',
#   'A Simple Game Engine based on Html5',
#   'None',
#   'Build-a-Perfect-React-Form-with-Hook',
#   'Build a Perfect  React Form with Hook',
#   'None',
#   'builderbook',
#   'Open source web application to learn JS stack: React, Material-UI, Next.js, Node.js, Express.js, Mongoose, MongoDB database.',
#   'None',
#   'bUnit',
#   'A testing library for Blazor Components. You can easily define components under test in C# or Razor syntax and verify outcome using semantic HTML diffing/comparison logic. You can easily interact with and inspect components, trigger event handlers, provide cascading values, inject services, mock IJSRuntime, and perform snapshot testing.',
#   'None',
#   'butterfly',
#   'A distributed tracing system and  application performance management.',
#   'None',
#   'bvz-teste',
#   'None',
#   'None',
#   'C-Sharp',
#   'All algorithms implemented in C#.',
#   'None',
#   'C-Sharp-Automation',
#   'C# Stationary Automation - C# Form yapısı ile Kırtasiye Otomasyonu',
#   'None',
#   'calculadora_simples',
#   'Projeto de uma calculadora simples ',
#   'None',
#   'candidates-api',
#   'Public API used for the interview',
#   'None',
#   'candidates-front',
#   'Frontend to show filters and list for candidates',
#   'None',
#   'captainhook',
#   'Very flexible git hook manager for php developers',
#   'None',
#   'carbon',
#   ':black_heart: Create and share beautiful images of your source code',
#   'None',
#   'Cards',
#   'ASP NET Core API for adding product to Shopping Cart',
#   'None',
#   'Cards-1',
#   'none',
#   'None',
#   'cassette',
#   'A simple content-addressable storage system for .NET 4.5 and .NET Core',
#   'None',
#   'Cavallaro_Elegance_API',
#   'Cavallaro Elegance API CRUDE feito em aula Generation Brasil',
#   'None',
#   'cave-serene',
#   'Catasto delle attività estrattive multipiattaforma e multidatabase',
#   'None',
#   'cc-licenses',
#   'Creative Commons Licenses for Github',
#   'None',
#   'CefSharp',
#   'Build HTML Desktop Apps on .NET/.NET Core/.NET 5 using native GUI, HTML5, JavaScript, CSS',
#   'None',
#   'CH-inventory',
#   'This application tracks purchases and usage of production materials at a glassblowing studio.',
#   'None',
#   'ChannelsDemoInCSharp',
#   'None',
#   'None',
#   'charts',
#   'Simple, responsive, modern SVG Charts with zero dependencies',
#   'None',
#   'charts.css',
#   'Open source CSS framework for data visualization.',
#   'None',
#   'chat',
#   '💬 🐕  \u200e very chat. such messages. so talking. wow. React/Redux, TypeScript, Socket.io chat app.',
#   'None',
#   'chat-app',
#   'Realtime web chat made with node.js and socket.io',
#   'None',
#   'Chat-Realtime',
#   'Public & Private message. MySQL & Firebase.',
#   'None',
#   'ChatApp',
#   'A simple chat application using PHP Websockets',
#   'None',
#   'chatEngine-chat-app',
#   'real time chat app by react.js',
#   'None',
#   'ChayaBot',
#   'A Discord bot that can play music/game(s)',
#   'None',
#   'cicero',
#   'Accord Project Smart Templates Implementation',
#   'None',
#   'cinemaEcletico',
#   'None',
#   'None',
#   'ClassicASP',
#   'None',
#   'None',
#   'classicaspdocker',
#   'None',
#   'None',
#   'ClassicAspMVC',
#   'Classic ASP website implemented using MVC architecture',
#   'None',
#   'classicAspUnit',
#   'A classic ASP unit framework for helping in testing classic asp code.',
#   'None',
#   'clean-code-dotnet',
#   ':bathtub:  Clean Code concepts and tools adapted for .NET ',
#   'None',
#   'clean-code-javascript',
#   ':bathtub: Clean Code concepts adapted for JavaScript',
#   'None',
#   'clean-code-php',
#   ':bathtub: Clean Code concepts adapted for PHP',
#   'None',
#   'clean-code-project',
#   'Clean Code - React / Firebase Web App',
#   'None',
#   'clean-flutter-app',
#   'Aplicativo feito em Flutter usando TDD, Clean Architecture, Design Patterns e SOLID principles',
#   'None',
#   'Clean-login-system-template',
#   'Clean and simple Login system template for ASP.NET MVC along with Role (CRUD operations). Easy to set-up within a few minutes',
#   'None',
#   'clean-react',
#   'Sistema em ReactJs usando Hooks, Typescript, TDD, Clean Architecture, Design Patterns e SOLID principles',
#   'None',
#   'clean-ts-api',
#   'API em NodeJs usando Typescript, TDD, Clean Architecture, Design Patterns e SOLID principles',
#   'None',
#   'CleanArchitecture',
#   "Clean Architecture in ASP.NET Core 5.0 including JWT Authentication, Swagger, Versioning of API's, Automapper, Dependency Injection. ",
#   'None',
#   'CleanArchitecture-1',
#   'A starting point for Clean Architecture with ASP.NET Core',
#   'None',
#   'CleanArchitecture-2',
#   'Clean Architecture Solution Template for Angular 10 and .NET 5',
#   'None',
#   'CleanArchitecture-3',
#   'Clean Architecture Template for Blazor WebAssembly Built with MudBlazor Components.',
#   'None',
#   'CleanArchitectureNotes',
#   'This repo is keeping my progress of clean architecture reads.',
#   'None',
#   'CleanMoon.CSS',
#   'Stylesheet to fix rendering problems of browsers with css.',
#   'None',
#   'clean_react',
#   "Project developed for my medium's article about Clean Architecture in React",
#   'None',
#   'ClearScript',
#   'A library for adding scripting to .NET applications. Supports V8 (Windows, Linux, macOS) and JScript/VBScript (Windows).',
#   'None',
#   'Client',
#   'GitLab API v4 client for PHP',
#   'None',
#   'cliff-wp-plugin-boilerplate',
#   "Cliff's WordPress plugin boilerplate",
#   'None',
#   'clinic',
#   ' Project for the discipline of integrative topics',
#   'None',
#   'Clinic-Management-System-ASP.NET',
#   '👨\u200d⚕️ A fully featured Clinic Management System based on three tier architecture made using ASP.NET, C# with a well documented README.md file.',
#   'None',
#   'clmystery',
#   'Command Line Murder Mystery',
#   'None',
#   'clone_subito_aulab',
#   'None',
#   'None',
#   'cloud-carbon-footprint',
#   'Cloud Carbon Footprint is a tool to estimate energy use (kilowatt-hours) and carbon emissions (metric tons CO2e) from public cloud usage',
#   'None',
#   'clubedaleitura',
#   'App Clube da Leitura C#',
#   'None',
#   'CMS',
#   'Content Management System',
#   'None',
#   'Cocona',
#   'Micro-framework for .NET console application. Cocona makes it easy and fast to build console applications on .NET Core.',
#   'None',
#   'code',
#   'Code is a full-stack application that creates code and returns the id and code to the user.',
#   'None',
#   'code-dot-org',
#   'The code powering code.org and studio.code.org',
#   'None',
#   'code-workout',
#   'CodeWorkout: a programming practice and self-study web site',
#   'None',
#   'CodeFirstFunctions',
#   'Store Functions for EntityFramework CodeFirst',
#   'None',
#   'CodePractice',
#   'Code examples, best practices, testing and more',
#   'None',
#   'code_more_projects',
#   'Repo for lists of projects collected from code more: open source event',
#   'None',
#   'coding-string',
#   'First php project',
#   'None',
#   'CodingExamples',
#   'Some Example Java Codes',
#   'None',
#   'Comment-Widget',
#   'A highly customizable recent comments widget with avatars and excerpts.',
#   'None',
#   'Common.Testing.NUnit',
#   'Provides base class with generic methods for testing',
#   'None',
#   'community-telegram-bot',
#   'Funny and Stupid Telegram bot of OpenSource Support Group',
#   'None',
#   'community-toolbox',
#   'Tools to understand and welcome people into a contributor community',
#   'None',
#   'complete-web-developer-manual',
#   'All resources and notes from the Complete Web Developer in 2021: Zero to Mastery course',
#   'None',
#   'component-library',
#   'None',
#   'None',
#   'component-library-examples',
#   'Example components & styling solutions for the Code.org component library.',
#   'None',
#   'Components',
#   'ReactJS components I love',
#   'None',
#   'components-1',
#   "The Serverless Framework's new infrastructure provisioning technology — Build, compose, & deploy serverless apps in seconds...",
#   'None',
#   'computer-science',
#   ':mortar_board: Path to a free self-taught education in Computer Science!',
#   'None',
#   'ConceitosPOOCSharp',
#   'Objetivo do repositório: Centralizar os conhecimentos fundamentais de programação orientada a objetos.',
#   'None',
#   'ConnectingXML',
#   'Connecting XML files',
#   'None',
#   'Constructors',
#   'None',
#   'None',
#   'ContactForms',
#   'ASP.NET Core 5 Contact Form Sample',
#   'None',
#   'content',
#   'The content behind MDN Web Docs',
#   'None',
#   'contribute-to-open-source',
#   'Learn the GitHub workflow by contributing code in a fun simulation project ',
#   'None',
#   'Contribute-To-This-Project',
#   'This project is waiting for your contribution. If you have never contributed code on GitHub before, this is the project to get you started.',
#   'None',
#   'contributors-posts',
#   'This plugin is useful for those who want to add to your blog Columnists or other Characters without having to create new WordPress Users, you can associate these contributors also to pages and posts.',
#   'PHP',
#   'Convey',
#   'A simple recipe for .NET Core microservices.',
#   'None',
#   'coolstore-moduliths',
#   'The coolstore website on modular monolith approach',
#   'None',
#   'copy-code-block',
#   'A solution to display code in the browser and copy it to the clipboard',
#   'None',
#   'Core',
#   'An ultra-fast, light-weight MVC framework developed for ASP.NET Core that uses a powerful HTML templating engine, supports RESTful web services, includes an extensible security system, and is simple to setup & configure.',
#   'None',
#   'core-1',
#   'All of the required core code',
#   'None',
#   'core5template',
#   'None',
#   'None',
#   'Corso_PHP_ITS',
#   'Repository del corso PHP Programming per Backend Developer, ITS - ICT Piemonte',
#   'None',
#   'Cosmos',
#   'Cosmos is an operating system "construction kit". Build your own OS using managed languages such as C#, VB.NET, and more!',
#   'None',
#   'Courses',
#   'None',
#   'None',
#   'coverlet',
#   'Cross platform code coverage for .NET',
#   'None',
#   'Covid-19-Dashboard',
#   'Fetch dei dati dalla Protezione Civile, progetto interamente costruito con JavaScript Vanilla e Bootstrap 5',
#   'JavaScript',
#   'COVID-19-Tracker',
#   'COVID-19-Tracker',
#   'None',
#   'Covid-Dashboard-Frontend',
#   'Covid-19 Dashboard Frontend',
#   'None',
#   'Cowboy',
#   'Cowboy.Sockets is a C# library for building sockets based services.',
#   'None',
#   'coyote',
#   'Coyote is a tool designed to help ensure that your C# code is free of annoying concurrency bugs.',
#   'None',
#   'CQRSInDotnetCore',
#   'An overview of CQRS in .NET Core 5',
#   'None',
#   'CqrsInPractice',
#   'Source code for the CQRS in Practice Pluralsight course',
#   'None',
#   'cra-recipe',
#   'Step-by-step guide to bootstrap a CRA app from scratch.',
#   'None',
#   'cra-universal',
#   '🌏 Create React App companion for universal app. No eject, auto SSR, zero config, full HMR, and more',
#   'None',
#   'craft',
#   'Top-down 2D game engine for the Craft app type.  See NOTICE for restrictions on use.',
#   'None',
#   'crashCourses',
#   'Crash Courses',
#   'None',
#   'create-and-seed-db',
#   'Practice seeding a database from a seed file.',
#   'None',
#   'create-component-app',
#   'Tool to generate different types of React components from the terminal. 💻',
#   'None',
#   'create-guten-block',
#   ' 📦    A zero-configuration #0CJS developer toolkit for building WordPress Gutenberg block plugins.',
#   'None',
#   'create-html5-boilerplate',
#   'npx quick start for html5-boilerplate',
#   'None',
#   'create-micro-react-app',
#   '✨  Create a microfrontend architecture as simple as CRA.',
#   'None',
#   'create-react-app-redux',
#   'React Router, Redux, Redux Thunk & Create React App boilerplate',
#   'None',
#   'create-react-component-folder',
#   'Creates react component folder structure',
#   'None',
#   'create-react-library',
#   '⚡CLI for creating reusable react libraries.',
#   'None',
#   'create-react-library-1',
#   "React NPM library starter kit based on Facebook's create react app",
#   'None',
#   'create-react-microservice',
#   '🚀 Create highly scalable and universal React microservices/applications within seconds.',
#   'None',
#   'create-wp-react-app',
#   'Create React WordPress plugin with no build configuration.',
#   'None',
#   'Crm',
#   'None',
#   'None',
#   'Crm-Frontend',
#   'None',
#   'None',
#   'cron-translator',
#   '⏰️ Makes CRON expressions human-readable',
#   'None',
#   'Cron.Core',
#   'Cron Builder object that can be used to build Cron expressions, describe Cron expressions, and manipulate cron expressions..',
#   'None',
#   'CRUD',
#   'CRUD (Create, Read, Update and Delete) with PHP using PDO',
#   'None',
#   'crud-1',
#   'CRUD is a backend application that has user crud.',
#   'None',
#   'crud-frontend',
#   'Small project to represent the use of api methods (CRUD) in the frontend.',
#   'None',
#   'CRUDApp',
#   'Built with React.JS and Spring Boot.',
#   'None',
#   'crunz',
#   'A PHP-based job scheduler',
#   'None',
#   'CSharp-PatternHouse',
#   'Destination for all Symbolic, Alphabetic, Numeric, Wave, Series and Pyramid Patterns using looping constructs in C#',
#   'None',
#   'csharp-playground',
#   'None',
#   'None',
#   'csharp-testing-playground',
#   'None',
#   'None',
#   'CSharpCodingStandard',
#   'This is the Standard for C# Programming language',
#   'None',
#   'CSharpIntro',
#   'None',
#   'None',
#   'Csharp_Hospital_Database_Management',
#   'This is a Basic Hospital Database Management System done using C# ,Visual Studio winForms Application (.NET Framework)',
#   'None',
#   'css-protips',
#   'A collection of tips to help take your CSS skills pro',
#   'None',
#   'csshake',
#   'CSS classes to move your DOM!',
#   'None',
#   'cssONLY',
#   'Solutions to various frontend design challenges in web development.',
#   'None',
#   'csv-to-sql',
#   'CSV extract to database (database : PostgreSQL, with UnitTest)',
#   'None',
#   'CS_App',
#   'None',
#   'None',
#   'curriculum',
#   'The open curriculum for learning web development',
#   'None',
#   'curso_web_moderno',
#   'None',
#   'None',
#   'cusdis',
#   'lightweight, privacy-friendly alternative to Disqus.',
#   'None',
#   'custom_e-commerce',
#   'None',
#   'None',
#   'CV',
#   'CV template',
#   'None',
#   'CyberCodeOnline',
#   'Cyberpunk inspired MMORPG that looks like VS Code, built with React.js',
#   'None',
#   'cypress',
#   'Fast, easy and reliable testing for anything that runs in a browser.',
#   'None',
#   'cypress-api-tests-demo',
#   'This repository contains the code for the article, Cypress and API Tests in 5 Minutes',
#   'None',
#   'cypress-cucumber-preprocessor',
#   'Run cucumber/gherkin-syntaxed specs with cypress.io',
#   'None',
#   'cypress-cucumber-tests',
#   'None',
#   'None',
#   'cypress-realworld-app',
#   'A payment application to demonstrate real-world usage of Cypress testing methods, patterns, and workflows.',
#   'None',
#   'Cypress-Testing',
#   'None',
#   'None',
#   'daf-ontologie-vocabolari-controllati',
#   'Elenco di ontologie e vocabolari controllati. Per maggiori informazioni, si veda il readme principale e quello di singoli vocabolari/ontologie, ove presente, e la seguente documentazione',
#   'None',
#   'Dashboard-Covid-19-Personale',
#   'Dashboard con dati sulla diffusione del Covid-19 della protezione civile, sviluppato con Bootstrap 4.5 e JavaScript. per i grafici è stata utilizzata la libreria Chart.js',
#   'None',
#   'Datasets',
#   'Collection of data/datasets for public use',
#   'None',
#   'datatables',
#   'PHP Library to handle server-side processing for Datatables, in a fast and simple way.',
#   'None',
#   'datdot',
#   'website',
#   'None',
#   'dati.gov.it',
#   'dati.gov.it: il sito degli opendata italiani',
#   'None',
#   'DatingApp',
#   'None',
#   'None',
#   'db-first',
#   'Used cars database entity relationship diagram',
#   'None',
#   'db-first-1',
#   ...],
#  ['AmitKumarApp',
#   'React Native task ',
#   'Java',
#   'amitntrivedi',
#   'None',
#   'None',
#   'article',
#   'This repository contains all the source code I am referring on my blog site amitntrivedi.com ',
#   'JavaScript',
#   'asteroid',
#   'React Native App. Demo use of API call and NativeBase.io UI',
#   'JavaScript',
#   'blog',
#   'None',
#   'PHP',
#   'campusgem',
#   'None',
#   'PHP',
#   'grocery',
#   'React JS event handling in nested component ',
#   'JavaScript',
#   'JavascriptConcepts',
#   'Few code snippets to demonstrate how JavaScript works ',
#   'JavaScript',
#   'mBnk',
#   'None',
#   'JavaScript',
#   'meals',
#   'Meal App. The Demo app created in React Native to demonstrate features like Navigation (Top, Bottom). ',
#   'JavaScript',
#   'MyCart',
#   'Basic shopping cart built using React Native, Redux, and Firebase. ',
#   'JavaScript',
#   'ObjectOrientedConceptsandProgramming',
#   'Object Oriented Concepts and Programming  using C++. ',
#   'C++',
#   'PRYDAN-CRM-API',
#   'Azure Deployment ',
#   'HTML',
#   'prydan-dashboard',
#   'Dashbaord with React JS',
#   'JavaScript',
#   'ReduxReactNative',
#   'Redux Emaple for Begninners ',
#   'Java',
#   'search-movies',
#   'Search Movies Basic features of Calling API ',
#   'JavaScript',
#   'ShoppingCart',
#   'None',
#   'None',
#   'stock-dog',
#   'My code while following tutorial on building an Angular application',
#   'JavaScript',
#   'todo',
#   'Demo React JS app for Redux and Storing data on the cloud firebase. ',
#   'JavaScript'],
#  ['Complete-Python-3-Bootcamp',
#   'Course Files for Complete Python 3 Bootcamp Course on Udemy',
#   'None',
#   'crye',
#   'None',
#   'None',
#   'Front-end-Developer-Interview-Questions',
#   'A list of helpful front-end related questions you can use to interview potential candidates, test yourself or completely ignore.',
#   'None',
#   'github-slideshow',
#   'A robot powered training repository :robot:',
#   'Ruby',
#   'hello-world-MEEEE-',
#   'My repository GitHub PRAK',
#   'None',
#   'infinitelyDeepNeuralNetworks',
#   'Deep Learning without any depth limitation ',
#   'Python'],
#  ['Authentication-Secrets',
#   'None',
#   'EJS',
#   'basic-chess-game',
#   'None',
#   'JavaScript',
#   'CodeAndStuff',
#   'Competitive programming, algorithms, data structures...etc.',
#   'C++',
#   'FindX_Math_Quiz_Generator',
#   'Source code of the android app FindX - Math Quiz Generator (goo.gl/WolULe)',
#   'Java',
#   'hetp111',
#   'None',
#   'None',
#   'LoginRegister',
#   'Register and Login System in PHP and MySQL (goo.gl/tc6qVm)',
#   'PHP',
#   'MLAndStuff',
#   'None',
#   'Jupyter Notebook',
#   'ReactJS-examples',
#   'None',
#   'JavaScript',
#   'sympy',
#   'A computer algebra system written in pure Python',
#   'Python',
#   'Wiki-API',
#   'None',
#   'JavaScript'],
#  ['AppAny.HotChocolate.FluentValidation',
#   'Input field HotChocolate GraphQL + FluentValidation integration',
#   'None',
#   'AppAny.Quartz.EntityFrameworkCore.Migrations',
#   'EntityFrameworkCore PostgreSQL migrations for Quartz.NET',
#   'None',
#   'AspNetCore',
#   'None',
#   'TypeScript',
#   'C-Labs',
#   'None',
#   'C++',
#   'DesignPatterns',
#   'None',
#   'C#',
#   'EntityFrameworkCore',
#   'None',
#   'C#',
#   'Gallery',
#   'None',
#   'TypeScript',
#   'GameServer',
#   'None',
#   'C#',
#   'Import',
#   'None',
#   'C#',
#   'Injection',
#   'None',
#   'C#',
#   'LinqLinqLinq',
#   'None',
#   'C#',
#   'Minio.AspNetCore',
#   'AspNetCore integration for Minio client',
#   'None',
#   'RusherMicroController',
#   'None',
#   'C#',
#   'RusherNetLib',
#   'None',
#   'C#',
#   'RusherTelegramApi',
#   'None',
#   'C#',
#   'Shaykhullin',
#   'None',
#   'C#',
#   'Shaykhullin.DependencyInjection',
#   'None',
#   'C#',
#   'Shaykhullin.Network',
#   'None',
#   'C#',
#   'Shaykhullin.ObjectOrientedProgramming',
#   'None',
#   'C#',
#   'Shaykhullin.Practise',
#   'None',
#   'C#',
#   'Shaykhullin.ProgrammingTechnologies',
#   'None',
#   'C#',
#   'Shelter',
#   'None',
#   'C#',
#   'StateMachine',
#   'None',
#   'C#'],
#  ['Docs',
#   'None',
#   'None',
#   'FoodCollectionForNGO',
#   'None',
#   'Java',
#   'GAN-Regret-Minimization',
#   'A regret minimization approach to training Generative Adversarial Networks (GANs). This was my project in the "Algorithms and Optimization for Big Data" course.',
#   'None',
#   'GestureDetection',
#   'None',
#   'Python',
#   'IISc',
#   'MSc Thesis',
#   'Jupyter Notebook',
#   'IMSc',
#   'None',
#   'None',
#   'matrix-inversion-verilog',
#   'Behavioral implementation for inverting a 5X5 matrix',
#   'Verilog',
#   'NAB',
#   'The Numenta Anomaly Benchmark',
#   'Python',
#   'Perm-Approx',
#   'Matrix Permanent Approximation',
#   'Jupyter Notebook',
#   'Zippel',
#   "Implementation of a Zippel's sparse polynomial interpolation algorithm",
#   'Python'],
#  ['7UP-7Down',
#   'Webapp containing the 7UP-7Down Game',
#   'HTML',
#   'Basketball-ScoreKeeper',
#   'None',
#   'Java',
#   'camera-app',
#   'None',
#   'JavaScript',
#   'ChatBot',
#   'None',
#   'Jupyter Notebook',
#   'CleanPy',
#   'Organizes files in folders and helps you to clean your PC',
#   'None',
#   'CodeManiacs',
#   'IIT Mandi Online Judge',
#   'None',
#   'cups',
#   'OpenPrinting CUPS Sources (Apple CUPS + common patches)',
#   'C',
#   'cups-filters',
#   'filters, backends, cups-browsed, ... - Everything which CUPS needs to be used on non-Mac systems',
#   'C',
#   'devbae-blog',
#   'DevBae Tech Blog',
#   'HTML',
#   'githero',
#   'Githero Challenge for Utkarsh 2k19.',
#   'None',
#   'Hacking-Google-Maps',
#   'Repo for solutions of Hacking Google Maps!',
#   'None',
#   'HelpHub',
#   'The WordPress user documentation portal',
#   'None',
#   'intro',
#   'The Intro Page',
#   'None',
#   'kamandprompt.github.io',
#   'Kamandprompt Open Source Website',
#   'CSS',
#   'kp-sys-admin',
#   'None',
#   'None',
#   'kraken-game',
#   'None',
#   'C#',
#   'maia',
#   'None',
#   'Jupyter Notebook',
#   'munich',
#   'None',
#   'Python',
#   'musin',
#   'An android app to easily download songs',
#   'None',
#   'openprinting.github.io',
#   'Organization Pages for OpenPrinting',
#   'None',
#   'patentclassifier-1',
#   'None',
#   'HTML',
#   'pi_video_looper',
#   'Application to turn your Raspberry Pi into a dedicated looping video playback device, good for art installations, information displays, or just playing cat videos all day.',
#   'Python',
#   'pranshukharkwal.github.io',
#   'None',
#   'HTML',
#   'song-downloader',
#   'One click song downloader',
#   'HTML',
#   'todolist',
#   'None',
#   'CSS',
#   'wayback-machine-chrome',
#   'A chrome browser extension',
#   'JavaScript',
#   'weather-app',
#   'Weather App - This webapp displays the weather of a particular city. Just enter the name of the city and press enter.',
#   'CSS',
#   'WeCare',
#   'Hackfinity Event',
#   'JavaScript',
#   'zulip',
#   'Zulip server - powerful open source team chat',
#   'None'],
#  ['15pratik.github.io',
#   'None',
#   'HTML',
#   'Automate-The-Boring-Stuff-Solutions',
#   'Chapter-wise solutions of "Automate the Boring Stuff with Python" book by Al Sweigart. Contains only unsolved projects.',
#   'Python',
#   'aws-sdk-java',
#   'The official AWS SDK for Java.',
#   'Java',
#   'CountryCatalogue',
#   'Build a structures to hold the information about countries and continents and filter them based on several categories and filters.',
#   'Python',
#   'deployment-toolkit',
#   'deployment-toolkit',
#   'Python',
#   'encrypted-distributed-file-storage',
#   'Distributed file storage across cloud accounts with encryption using Chinese Remainder Theorem',
#   'Java',
#   'FileEncDec',
#   'Encryption and Decryption of files using AES 256 and base 64 encoding on the file name.',
#   'C',
#   'Hackathon-A.I.M.',
#   'None',
#   'None',
#   'Hacknight',
#   'ML based Learning Product',
#   'HTML',
#   'Java',
#   'All Algorithms implemented in Java',
#   'Java',
#   'MatrixInverse',
#   'Inverse of a 5*5 matrix in verilog',
#   'Verilog',
#   'storage-blobs-java-quickstart',
#   'Code for QuickStart article for accessing Blobs with Java',
#   'Java',
#   'TwitterSentimentalAnalysis',
#   'The “happiness score” for a single tweet is found by looking for certain keywords in a tweet and for each keyword found in that tweet totaling their “sentiment values”. The “happiness score” for each timezone is computed.',
#   'Python',
#   'Twitter_Timeline',
#   'PHP script to access user tweets, follower tweets and list of followers',
#   'PHP',
#   'VSM_admin_panel',
#   'Admin Panel for the application VSM',
#   'JavaScript',
#   'zaproxy',
#   'The OWASP ZAP core project',
#   'Java'],
#  ['450-DSA-Questions',
#   '450- DSA Questions 🔥🔥',
#   'None',
#   'A-Sip-of-Wine-Wine-Quality-Predictor',
#   'A Sip of Wine is a wine quality predictor. Various algorithms like Decision Tree classifier, gradient boosting classifier and random forest classifier were used to make predictions. Based on various evaluation metrics, the GBM tree classifier emerged as the favoured classifier with an F score of 89%. A feature analysis was also done to show the most relevant features for making prediction.',
#   'None',
#   'Adult-Income-Analysis',
#   'Exploratory data analysis for the Adult or Census Income dataset from UCI Machine Learning Repository : https://archive.ics.uci.edu/ml/datasets/adult',
#   'None',
#   'Alice-in-Zomaland',
#   'Used Selenium Webdriver in Python and Zomato API to scrape reviews and ratings of famous food bloggers. Cleaned and analysed the gathered data to try and sensitive information like their frequently visited places, and home and office locations.',
#   'None',
#   'Analysing-and-Forecasting-India-s-AQI',
#   "EDA of India's AQI data to study COVID 19's impact on air quality and time series modelling with statsmodels to forecast future AQI values",
#   'None',
#   'API-Calls-in-Java',
#   'This particular section shows how to expose APIs in Spring boot project',
#   'Java',
#   'ApplicationProperties_SpringBoot',
#   'All fields of application.properties file in Spring Boot',
#   'None',
#   'applied-machine-learning',
#   'This repository will hold my experiments in both supervised and unsupervised machine learning tasks.',
#   'None',
#   'article-aug31-reactive-crud-rest-api-using-spring-boot-spring-data-r2dbc',
#   'Source code for article published @ http://2much2learn.com/crud-reactive-rest-api-using-springboot-springdata-r2dbc/',
#   'None',
#   'Artificial-Intelligence-with-Python',
#   'Code repository for Artificial Intelligence with Python, published by Packt ',
#   'None',
#   'Async-Message-Communication',
#   'Java application which is able to communicate messages from source to destination ansynchronously.',
#   'None',
#   'automatic-helmet-detection',
#   'Video Analysis using Machine Learning',
#   'None',
#   'Autoranking-Amazon-Reviews',
#   'Ranking the reviews on amazon according to their helpfulness',
#   'None',
#   'awesome-computer-science-resources',
#   'List of All awesome Computer Science Courses',
#   'None',
#   'awesome-github-profiles',
#   'List of GitHub profiles that have awesome customisation, that you can use for inspiration',
#   'None',
#   'AWSTerraformPOC',
#   'Contains the code for Terraform, Spring Boot, React used in AWS POC',
#   'None',
#   'Bank-Personal-Loan-ML-Problem',
#   'Logistic Regression problem',
#   'None',
#   'Bird-Species-Classification',
#   'A private competition held on Kaggle classifying images of birds into 140 separate species',
#   'None',
#   'bokeh',
#   'Interactive Data Visualization in the browser, from  Python',
#   'None',
#   'CAP-Theorem',
#   'CAP Theorem and supported Dbs',
#   'None',
#   'Cardinality-Estimation-Multiset-Convolutional-Networks',
#   'Predicting the cardinality of database given the query using a network called Multiset Convolutional network.',
#   'None',
#   'cern-hflav-swan',
#   'In-browser interactive averaging of CERN collision data from the Large Hadron Collider Beauty Experient (LHC-b)',
#   'None',
#   'certified-kubernetes-application-developer',
#   'None',
#   'None',
#   'chandrikadeb7',
#   'None',
#   'None',
#   'Chess',
#   'Chess simulation. Click on the piece to move, and the location to move it to. If the action is legal, it will be taken. The game is done once a King enters checkmate, or once there is a draw.',
#   'None',
#   'ckad-crash-course',
#   'In-depth and hands-on practice for acing the exam.',
#   'None',
#   'CKAD-exercises',
#   'A set of exercises to prepare for Certified Kubernetes Application Developer exam by Cloud Native Computing Foundation',
#   'None',
#   'CKAD-resources',
#   'Study materials for k8s CKAD',
#   'None',
#   'Cloud-Design-Patterns',
#   'None',
#   'Java',
#   'Cloud_Config_Server_And_Client_JavaApp',
#   'This example explains how to read a git configuration associated with a client using a config server app.',
#   'None',
#   'codeSTACKr',
#   'None',
#   'None',
#   'code_snippets',
#   'None',
#   'None',
#   'Coding-Ninjas-java-',
#   "This is just to keep track of my progress of my courses Programming in Java and Data Structures that I've done in Coding ninjas. ",
#   'None',
#   'comparative-study-of-frameworks-for-parallel-processing-of-graphs',
#   'My Final Paper',
#   'None',
#   'ConcurrentModificationException',
#   'ConcurrentModificationException in List and HashMap iteration',
#   'None',
#   'Contract-of-Equals-and-Hashcode-in-Java',
#   'This is a small example using HashMap to explain usage of equals and hashcode',
#   'Java',
#   'CoronaVirus-Updates',
#   'A script for getting real time data about the coronavirus cases in INDIA. This Python script fetches the live data from Ministry of Health Affairs Official Website. Then data is represented in the horizontal bar graph.',
#   'None',
#   'course-content',
#   'NMA Computational Neuroscience course',
#   'None',
#   'coursera-deep-learning-specialization',
#   'Notes, programming assignments and quizzes from all courses within the Coursera Deep Learning specialization offered by deeplearning.ai: (i) Neural Networks and Deep Learning; (ii) Improving Deep Neural Networks: Hyperparameter tuning, Regularization and Optimization; (iii) Structuring Machine Learning Projects; (iv) Convolutional Neural Networks; (v) Sequence Models',
#   'None',
#   'Coursera-Test',
#   'Assignments of Coursera',
#   'CSS',
#   'COVID-19-DASHBOARD',
#   'This is a basic dashboard that will take input following from the user :  Countries/Continents user is intrested in The of data he wants to visualize : Deaths/cases per day /Cummulative deaths/cases (Increase in No. of Deaths/Cases with time) The type of graph : (i) Line graph for Deaths/Cases type of queries (ii) Pie-chart for distribution queries between country/continents (iii) Bar graph for Comparision',
#   'None',
#   'COVID-19-Dashboard-using-lwc',
#   'None',
#   'None',
#   'CrackingHashedPassword',
#   'Simple way to crack a hash value of a password using Hashcat',
#   'None',
#   'cs228-material',
#   'Teaching materials for the probabilistic graphical models and deep learning classes at Stanford',
#   'Jupyter Notebook',
#   'data-science-portfolio',
#   'Portfolio of data science projects completed by me for academic, self learning, and hobby purposes.',
#   'None',
#   'Data-Visualization',
#   'Visualization of Data using Python',
#   'Jupyter Notebook',
#   'DB-Optimization-and-Fine-Tuning',
#   'Indexing for improving the DB operations ',
#   'None',
#   'Deep-Learning',
#   'A dive into the era of Machines',
#   'Jupyter Notebook',
#   'deep-learning-with-python-notebooks',
#   'Jupyter notebooks for the code samples of the book "Deep Learning with Python"',
#   'None',
#   'Delay-in-java',
#   'How to give delay without Thread.sleep() in Java',
#   'None',
#   'Different-HashMaps-in-Java',
#   'Differences between HashMap, LinkedHashMap, TreeMap',
#   'None',
#   'Digital-Image-Processing-Project',
#   'Code developed and successfully demonstrated as a part of the Digital Imaging Project on Coffee Bean Sampling, Imaging and Batch Sorting (Ocatve image pkg + ResNet34)',
#   'None',
#   'DownloadGithubProjects',
#   'None',
#   'None',
#   'EffectiveJava',
#   'None',
#   'Java',
#   'Email-Classification',
#   'Used NLP for pre-processing and implementation of various classifiers on email dataset to find a classifier that optimally classifies emails into respective category of spam and non-spam.',
#   'None',
#   'Energy-Efficiency-Enhancement-using-Neural-Networks',
#   'Assessing the heating load and cooling load requirements of buildings as a function of building parameters.',
#   'None',
#   'Everything-at-one-place',
#   'All you need to know in Java',
#   'None',
#   'Face-Mask-Detection-using-Detectron2-and-Faster-RCNN',
#   'Performing face detection using Detectron2 and Faster RCNN model by preprocessing & augmenting Kaggle dataset ',
#   'None',
#   'Face_Eyes_Smile-Detection',
#   'Simple OpenCV code for face, eyes and smile/mouth detection.',
#   'None',
#   'facial-expression-recognition',
#   'None',
#   'None',
#   'FoodDeliveryTimeCalculatorService',
#   'None',
#   'Java',
#   'Generic-Way-to-Make-All-API-Calls',
#   'This example shows how to make HTTP PUT, POST, DELETE, GET calls in a generic way using RestTemplate',
#   'Java',
#   'Git-Commands',
# ...
#   'None',
#   'SCSS',
#   'FitGeneix',
#   'None',
#   'SCSS',
#   'Flutter-Mini-Challenge',
#   'This is an App Created for the Mini-Challenge for Flutteristas',
#   'Dart',
#   'gh-action-open-source-labels',
#   'Issue labels using Open Source labels standards',
#   'None',
#   'github-actions-cron',
#   'Example of running a Node.js script on a schedule via Github Actions.',
#   'None',
#   'github-slideshow',
#   'A robot powered training repository :robot:',
#   'Ruby',
#   'gitpod',
#   'Gitpod automates the provisioning of ready-to-code development environments. ',
#   'None',
#   'Hacktoberfest-animations',
#   'Small animation selector for Hacktoberfest',
#   'CSS',
#   'Hacktoberfest2021',
#   'Curated list of beginner-friendly issues for Hacktoberfest 2021 | Raise PR to add your issues',
#   'None',
#   'Hello-World_Dart-App',
#   'None',
#   'Dart',
#   'layer5',
#   'Layer5, the service mesh company, representing every service mesh',
#   'JavaScript',
#   'Mini-3D-Adventures',
#   'A Collection of Mini WebGL Renders using Custom Blender Models.',
#   'JavaScript',
#   'MLDLS2021',
#   'None',
#   'Jupyter Notebook',
#   'MLH_challenge',
#   'for the mlh merge a github pull request',
#   'Nim',
#   'ModelComponentTest',
#   'None',
#   'JavaScript',
#   'nestjs-astra-module',
#   'Nest.js-Astra Module for Eddiehub-Project',
#   'None',
#   'object-gui',
#   'Object GUI - Javascript Object GUI Editor',
#   'TypeScript',
#   'oneledger-challenge',
#   'One Ledger Challenge for BorderHacks',
#   'None',
#   'Portfolio-Website',
#   "Prathamesh Shanbhag's Portfolio Website.🛠  I create interactive experiences within the Browser.✨",
#   'JavaScript',
#   'Prathamesh-Shanbhag',
#   'None',
#   'None',
#   'Productiwitty',
#   'A Productivity Web App to maximize productivity by bringing all web apps under one single banner.',
#   'JavaScript',
#   'progate-github-demo',
#   'None',
#   'None',
#   'progate-web-extravaganza',
#   'None',
#   'None',
#   'Python-Beginners',
#   'A list of 50 programs for beginners in python',
#   'Python',
#   'react-portfolio',
#   'None',
#   'None',
#   'Seaoras',
#   'None',
#   'HTML',
#   'Socialy',
#   'None',
#   'JavaScript',
#   'Sorting',
#   'None',
#   'C',
#   'stargate',
#   'Discord bot using Stargate',
#   'None',
#   'support',
#   'Community Help & Support and AEA (Ask Everyone Anything)',
#   'None',
#   'Truemato',
#   'Angular Based Food Ordering Website',
#   'SCSS',
#   'typesense-website',
#   'Typesense website and documentation | An open source search engine alternative to Algolia & Typesense',
#   'None',
#   'Unknown-Roads',
#   'A Tour Company Dummy website created using just HTML ,CSS and Vanilla Javascript!',
#   'SCSS',
#   'Violent-Sea',
#   'A Sea of Color Changing Waves that you can Control using the Debug Panel',
#   'JavaScript',
#   'Waveportal',
#   'None',
#   'JavaScript'],
#  ['Car-racing-game',
#   'None',
#   'HTML',
#   'College-Management-System',
#   'Build a College Management System using File Management concept in C language',
#   'C',
#   'Competitive-Programming-CP',
#   'None',
#   'None',
#   'contact-us-react',
#   'Contact Us Component in React with animations',
#   'None',
#   'cp-codeforces',
#   'None',
#   'C++',
#   'DBMS_notes',
#   'None',
#   'None',
#   'jinesh0109',
#   'None',
#   'None',
#   'visualizaing_and_predicting_stocks',
#   'None',
#   'None',
#   'Voice-Recongnition-Project',
#   'Build a Speech Recognition Project using correlation concept with a basic UI in Scilab',
#   'Scilab',
#   'WMC_Student_Companion',
#   'None',
#   'None'],
#  ['blood-donor',
#   'A full stack restful Application to connect with real time donors for voluntary blood donation.',
#   'Java',
#   'blood-donor-backend',
#   'A full stack restful Application to connect with potential blood donors in real time for voluntary blood donation.',
#   'Java',
#   'coding-interview-university',
#   'A complete computer science study plan to become a software engineer.',
#   'None',
#   'Coursera-Data-Structures-and-Algorithms-Specialization',
#   'Master Algorithmic Programming Techniques. Learn algorithms through programming and advance your software engineering or data science career',
#   'None',
#   'github-slideshow',
#   'A robot powered training repository :robot:',
#   'Ruby',
#   'login-registration-backend',
#   'None',
#   'None',
#   'problem-solving',
#   'None',
#   'None',
#   'Quiz_App_CLI',
#   'None',
#   'Python',
#   'spring-boot-fullstack-professional',
#   'Spring Boot Full Stack with React for Professionals',
#   'None',
#   'spring-boot-react-fullstack',
#   'None',
#   'None',
#   'spring-security-registration',
#   'Go further into "Learn Spring Security": ',
#   'None',
#   'system-design-primer',
#   'Learn how to design large-scale systems. Prep for the system design interview.  Includes Anki flashcards.',
#   'None',
#   'taha-yasin',
#   'None',
#   'None',
#   'Voluntary-Blood-Donor-UI',
#   'A full stack web Application for users who require blood or who are willing to donate blood. BloodDonor promotes voluntary blood donations.',
#   'JavaScript'],
#  ['ADVISOR-API-DJANGO',
#   'None',
#   'None',
#   'Amazing-Python-Scripts',
#   '🚀 Curated collection of Amazing Python scripts from Basics to Advance with automation task scripts.',
#   'Jupyter Notebook',
#   'Blog_Website',
#   'None',
#   'Python',
#   'code_snippets',
#   'None',
#   'None',
#   'django-deployment-example',
#   'Repo for our Django Deployment Example',
#   'Python',
#   'Elektra',
#   '⚡ML powered Electricity Outage prediction⚡',
#   'None',
#   'Hospital-Management-System',
#   'None',
#   'JavaScript',
#   'HospitalManagementSystem',
#   'Hospital management System python',
#   'None',
#   'LAD-Laplacian-Anomaly-Detector',
#   'Graph-based image anomaly detection algorithm leveraging on the Graph Fourier Transform',
#   'None',
#   'NewsAggregator',
#   'None',
#   'HTML',
#   'Opportunity-Calendar-Frontend',
#   'Opportunity Calendar is the one-stop place to refer important opportunites available in tech-space like newly posted jobs, internships, hackathons, tech-conferences, scholarhsips etc.',
#   'None',
#   'QuizApp',
#   'Quiz Application for Competition',
#   'JavaScript',
#   'Rescue',
#   'Women Safety Website',
#   'HTML',
#   'Tic_Tac_Toe',
#   'None',
#   'HTML'],
#  ['basekernel',
#   'A simple OS kernel for research, teaching, and fun.',
#   'None',
#   'CSE523-Machine-Learning-AlphaElite',
#   'Product Recommendation System - A process used by amazon shopping app for recommending a product to a user based on certain aspects.',
#   'Jupyter Notebook',
#   'git_test',
#   'None',
#   'None',
#   'Heart-Disease-Predictor',
#   'None',
#   'Java',
#   'Library-management-system-in-C',
#   'None',
#   'C',
#   'Object-Tracking-based-on-Color',
#   'None',
#   'MATLAB',
#   'Physical-Layer-Security-in-Vehicular-Networks',
#   'A project in wireless communication domain.',
#   'MATLAB',
#   'Stock-Price-Visualization',
#   'None',
#   'Jupyter Notebook',
#   'TechBlogex',
#   'None',
#   'None',
#   'YardSell-in-JAVA',
#   'None',
#   'None'],
#  ['clubCamp',
#   'Clubs of University',
#   'HTML',
#   'Drum-Kit',
#   'None',
#   'JavaScript',
#   'DSA-GeeksClasses',
#   'DSA-Self Paced With Doubt Assistance Course Solutions in Python (Python 3)',
#   'None',
#   'DSA-Programs',
#   'A Repository containing pure problems of Data Structures and Algorithms.',
#   'Java',
#   'fayp',
#   'A basic site to know about the weather and map of the place.',
#   'HTML',
#   'fayp-App-',
#   'A basic app to know weather about a city using APIs',
#   'Java',
#   'IPL-Analysis',
#   "The aim of the project is to analyze the previous year's IPL data to get some interesting insights.",
#   'Jupyter Notebook',
#   'kavania2002',
#   'None',
#   'None',
#   'MAT248-AppliedLA-06-Maverick',
#   'None',
#   'Jupyter Notebook',
#   'MobiMart',
#   'MobiMart is a mobile shopping website.',
#   'CSS',
#   'My-Site-Udemy',
#   'None',
#   'CSS',
#   'pgHUB',
#   'None',
#   'JavaScript',
#   'portfolio',
#   'None',
#   'HTML',
#   'portfolio_app',
#   'None',
#   'C++',
#   'React-Django-Practice',
#   'None',
#   'Python',
#   'Simon-Game',
#   'None',
#   'JavaScript',
#   'todolist-v1',
#   'None',
#   'CSS'],
#  ['one-united',
#   'Linking the globe through a simplified easy to use concept',
#   'None'],
#  ['blog_post',
#   'None',
#   'JavaScript',
#   'Buzzy_Attendance_ENR200',
#   'None',
#   'EJS',
#   'jevinjivani2507',
#   'None',
#   'None',
#   'Modified_Hill_Cipher',
#   'None',
#   'Java'],
#  ['clubCalendar',
#   'Clubs of University',
#   'HTML',
#   'dbms-project-ecommerce',
#   'None',
#   'JavaScript',
#   'My-Site-Udemy',
#   'None',
#   'CSS',
#   'newapp',
#   'None',
#   'JavaScript',
#   'Podcast-page',
#   'None',
#   'Python',
#   'portfolio',
#   'None',
#   'HTML',
#   'prbl-repo',
#   'None',
#   'Python',
#   'Research-Internships-for-Undergraduates',
#   'List of Research Internships for Undergraduate Students',
#   'None',
#   'VoteChain',
#   'A voting platform for web3 orgs.',
#   'JavaScript'],
#  ['Affine-Cipher',
#   'None',
#   'Java',
#   'bmi-calculator-flutter-vatsaldp',
#   'angela yu inspired',
#   'Objective-C',
#   'feather-weatherApp-flutter-vatsaldp',
#   'angela yu inspired',
#   'Objective-C',
#   'vatsal-dp',
#   'None',
#   'None'],
#  ['Affine-Cipher',
#   'None',
#   'Java',
#   'Samarth1302',
#   'Config files for my GitHub profile.',
#   'None',
#   'url-shortener-website',
#   'None',
#   'HTML'],
#  [],
#  ['Club-portal',
#   'A simple website using nodejs as a major framework.',
#   'EJS',
#   'Competitive-coding',
#   'Solutions to competitive prgramming questions on codeforces and codechef.',
#   'C++',
#   'Image_Compression',
#   'None',
#   'Jupyter Notebook',
#   'priyanshu-28',
#   'Config files for my GitHub profile.',
#   'None',
#   'steptech-orientation',
#   'None',
#   'None'],
#  ['about-us-hackoheist-Team-Hariyali',
#   'about us page',
#   'HTML',
#   'CV',
#   'None',
#   'HTML',
#   'eduhub-website',
#   "Hey it's a community website so if you want to contrinute in this project then go through the README.md section and also click the link. Raise Genuine PRs only. Your PRs will be accepted, keep patience. Star This Repo. You aren't allowed to Update README.md. Welcoming developers, content writers, and programming enthusiasts.",
#   'None',
#   'facebook-login-layout',
#   'tried to create a layout which looks like clone of facebook',
#   'HTML',
#   'googlesolutions2021',
#   '"Instigating Destitution" Team of 4 members: Smriti Gupta, Tejas Manhas, Shri Vaishnavi Vinnakota and Pragati Priya ;   On the topic NoPoverty; Created a Website',
#   'HTML'],
#  ['silverwing-internship',
#   'internship on python for 2 weeks',
#   'CSS',
#   'Towing-manager',
#   'None',
#   'None'],
#  ['dsa-codes', 'None', 'Java', 'tindog.github.io', 'None', 'HTML'],
#  ['AI-Radio',
#   'This is a radio app where you can ask Alan AI to play some music.',
#   'None',
#   'AlarmClock',
#   'None',
#   'Java',
#   'AnimeX',
#   'An android app that shows anime wallpapers with the help of firebase',
#   'Java',
#   'backgroundColorchange',
#   'None',
#   'Java',
#   'Basic-Banking-Application',
#   'None',
#   'None',
#   'chillify',
#   'Music App made with flutter',
#   'None',
#   'CryptocurrencyApp',
#   'A crypto currency app to show details of various coins using api',
#   'Kotlin',
#   'geeksforgeeksdsa',
#   'None',
#   'Java',
#   'Hackerrankproblemsolving',
#   'None',
#   'Java',
#   'java-programs-',
#   'None',
#   'Java',
#   'Javalibraries',
#   'None',
#   'Java',
#   'loadingalertdialog',
#   'a loading alert dialog with cutomization',
#   'Java',
#   'mangekyo-sharigan',
#   'None',
#   'C',
#   'Multicolouredtext',
#   'multicolored text without using spannable class',
#   'Java',
#   'notificationcounter',
#   'notification counter feature with reset button',
#   'Java',
#   'number-guessing',
#   'its a number guessing game using c language',
#   'C',
#   'Realtimecovid19tracker',
#   'first android project',
#   'Java',
#   'scientificapplecalculator',
#   'ios theme calculator ',
#   'Java',
#   'transparentloginform',
#   'a transparent login form design ',
#   'Java'],
#  ['clubCalendar',
#   'Clubs of University',
#   'HTML',
#   'healing-hands',
#   'None',
#   'CSS',
#   'Pocket-Shower',
#   'Project in the water studio',
#   'HTML'],
#  [],
#  ['MeetSojitra', 'None', 'None'],
#  ['DSA-Programs',
#   'A Repository containing pure problems of Data Structures and Algorithms.',
#   'Java',
#   'kavania2002',
#   'None',
#   'None',
#   'Linear-Programming',
#   'None',
#   'Python',
#   'Maulik176',
#   'Config files for my GitHub profile.',
#   'None',
#   'Maulik176-',
#   'None',
#   'None',
#   'Maulik176.github.io',
#   'WEB-DEV BOOTCAMP SHAPAI',
#   'CSS',
#   'Maulik_Leetcode',
#   'Collection of LeetCode questions to ace the coding interview! - Created using [LeetHub](https://github.com/QasimWani/LeetHub).',
#   'Python',
#   'Maulik_ReactJS',
#   'Created with CodeSandbox',
#   'JavaScript',
#   'Netflix_Clone',
#   'Created with CodeSandbox',
#   'None',
#   'Netflix__Clone',
#   "Netflix's Landing Page clone created using HTML, CSS, JavaScript",
#   'HTML',
#   'Portfolio',
#   'Built a responsive portfolio website.',
#   'HTML',
#   'ShapeAI_Bootcamp_BWD_Reactjs',
#   'None',
#   'JavaScript',
#   'ShapeAI_Maulik_Ranadiive',
#   'Bootcamp on Basic web development with node.js and express server , 7 days free by ShapeAI',
#   'JavaScript'],
#  ['Aditya-Bhate',
#   'Read-me for my GitHub profile.',
#   'None',
#   'Android-Dev-Basics',
#   'Android development Basics using Java',
#   'Java',
#   'Awesome-interview-questions',
#   ':octocat: A curated awesome list of lists of interview questions. Feel free to contribute! :mortar_board: ',
#   'None',
#   'Bankist-WebApp',
#   '"Bankist" WebApp is a miniature clone of a bank which implements primary tasks such as Transfer money, Request for a loan, Close an account, Check current balance. To add on , all the transactions will be recorded as either withdrawal/deposit in the log.',
#   'JavaScript',
#   'Colorama-in-Python',
#   'None',
#   'Jupyter Notebook',
#   'cpp-cheatsheet',
#   'Modern C++ Cheatsheet',
#   'C++',
#   'Digital-Clock-using-Python-Tkinter',
#   '🔑 Tkinter is used to create a variety of GUI (Graphical User Interface) applications. Python when combined with Tkinter provides a fast and easy way to create GUI applications. Tkinter provides a powerful object-oriented interface to the Tk GUI toolkit.  🔑 Using Label widget from Tkinter and time module we retrieve system’s time.',
#   'Jupyter Notebook',
#   'Emails-with-Python',
#   'Python comes with the built-in smtplib module for sending emails using the Simple Mail Transfer Protocol (SMTP).',
#   'Jupyter Notebook',
#   'Errors-and-Exceptions-Handling-Python',
#   'None',
#   'Jupyter Notebook',
#   'Game-of-Thrones-Battles-Analysis',
#   'Demonstrate Exploratory Data Analysis using plots and graphs using the information extracted from text.',
#   'Jupyter Notebook',
#   'github-readme-stats',
#   ':zap: Dynamically generated stats for your github readmes',
#   'None',
#   'Guess-my-number',
#   'A small quick single-player game made using HTML, CSS and Javascript to manoeuvre DOM Manipulation .',
#   'JavaScript',
#   'GUIs-in-Python',
#   'Widget Basics, Widget Events, Widget Lists, Widget Styling, Interactive functionality with Python GUI !, Custom Widget',
#   'Jupyter Notebook',
#   'Interesting-Modules-To-play-with-in-Python',
#   'None',
#   'Jupyter Notebook',
#   'Modal-Window-Js',
#   'Modal Window is a really cool web Dev. feature which serves the purpose of website as well as taking care of UI and UX requirements !',
#   'CSS',
#   'Object-oriented-programming-with-Python',
#   'None',
#   'Jupyter Notebook',
#   'PatternPrinting-Python',
#   'None',
#   'Jupyter Notebook',
#   'Pig-Game-Js',
#   'Pig Game 🎲 (2-player game)',
#   'CSS',
#   'Project-1-Tic-Tac-Toe-BoardGame',
#   'A complete user-interactive board game made using Python !',
#   'Jupyter Notebook',
#   'Project-2-War-Card-Game',
#   'War (also known as Battle in the United Kingdom) is a simple card game, typically played by two players using a standard playing card deck!',
#   'Jupyter Notebook',
#   'Python-Generators-and-Decorators',
#   'None',
#   'Jupyter Notebook',
#   'Python-Web-Scraping',
#   'None',
#   'Jupyter Notebook',
#   'Some-Useful-Python-Modules',
#   'Unzipping and Zipping Files, Collections module, Math and Random Modules, Opening and Reading Files, Overview of Regular Expressions, Python Debugger, Timing your code, datetime module',
#   'Jupyter Notebook',
#   'Spambot-using-PyAutoGUI',
#   'Spam bot using PyAutoGUI',
#   'Jupyter Notebook',
#   'Verzeo_AI_Projects',
#   'Performed data analysis using python and implemented two projects - minor project and a major project.',
#   'Jupyter Notebook',
#   'Working-with-Images-in-Python',
#   'None',
#   'Jupyter Notebook']]

# %%
print(len(TwodList))
print(len(UserList))
# Out:
# 144
# 144

# %%
sna=pd.DataFrame(UserList)

# %%
sna.rename(columns={0:'user'}, inplace=True)

# %%
sna['Topics']=TwodList

# %%
sna.head(9)
# Out:
#                  user                                             Topics
# 0     Simone Paolucci  [.github, None, None, .NET-Core-Business-Layer...
# 1  Amit Kumar Trivedi  [AmitKumarApp, React Native task , Java, amitn...
# 2         ArreyBeatz   [Complete-Python-3-Bootcamp, Course Files for ...
# 3                 Het  [Authentication-Secrets, None, EJS, basic-ches...
# 4   ShaykhullinSergey  [AppAny.HotChocolate.FluentValidation, Input f...
# 5          Ativ Joshi  [Docs, None, None, FoodCollectionForNGO, None,...
# 6                None  [7UP-7Down, Webapp containing the 7UP-7Down Ga...
# 7      Pratik Padalia  [15pratik.github.io, None, HTML, Automate-The-...
# 8         Kush Sharma  [450-DSA-Questions, 450- DSA Questions 🔥🔥, Non...

# %%
# Now we will convert the List of tags into Strings for better Usability
sna['Topics']=sna['Topics'].apply(lambda x:[i.replace(" ","") for i in x])

# %%
# Now we will convert the List of tags into Strings for better Usability
sna['Topics']=sna['Topics'].apply(lambda x: " ".join(x))

# %%
sna.head()
# Out:
#                  user                                             Topics
# 0     Simone Paolucci  .github None None .NET-Core-Business-Layer a.n...
# 1  Amit Kumar Trivedi  AmitKumarApp ReactNativetask Java amitntrivedi...
# 2         ArreyBeatz   Complete-Python-3-Bootcamp CourseFilesforCompl...
# 3                 Het  Authentication-Secrets None EJS basic-chess-ga...
# 4   ShaykhullinSergey  AppAny.HotChocolate.FluentValidation Inputfiel...

# %%
# Converting everything to lowercase
sna['Topics']=sna['Topics'].apply(lambda x: x.lower())

# %%
from nltk.stem.porter import PorterStemmer
ps=PorterStemmer()
def stem(text):
    y=[]
    for i in text.split():
        y.append(ps.stem(i))
    string=" ".join(y)
    return string

# %%
# Stemming the Column
sna['Topics']=sna['Topics'].apply(stem)

# %%
# Approaches
# 1) Bag of Words
# 2) Word2Vec
# 3) tfidf
#  We will be using both Bag of Words and TF * IDF and will take the better one
from sklearn.feature_extraction.text import TfidfVectorizer
# Bag of Words Model
from sklearn.feature_extraction.text import CountVectorizer
cv=CountVectorizer(max_features=5000,stop_words='english')

# %%
vectors=cv.fit_transform(sna['Topics']).toarray()

# %%
# TF IDF

tfIdfVectorizer=TfidfVectorizer(use_idf=True,max_features=10000,stop_words='english')
tfIdf = tfIdfVectorizer.fit_transform(sna['Topics'])
# We will be using this vector, which is same as vectors
df = pd.DataFrame(tfIdf[0].T.todense(), index=tfIdfVectorizer.get_feature_names(), columns=["TF-IDF"])
df = df.sort_values('TF-IDF', ascending=False)
print (df.head(25))
# Out:
#              TF-IDF
# react      0.415889
# net        0.310439
# simple     0.204709
# php        0.196843
# asp        0.189544
# app        0.182484
# dotnet     0.155529
# redux      0.142383
# json       0.128557
# spring     0.123399
# netcore    0.118202
# js         0.111255
# core       0.105760
# api        0.100124
# mvc        0.093318
# wordpress  0.093318
# netcor     0.093318
# test       0.088492
# create     0.086480
# clean      0.086156
# angular    0.086156
# design     0.085689
# frontend   0.084361
# blog       0.082529
# form       0.080875
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
# Calculating the Cosine distance in the bag of words and TF IDF Model to find the similarity

from sklearn.metrics.pairwise import cosine_similarity 
similarity_bow=cosine_similarity(vectors)
similarity_tfidf=cosine_similarity(tfIdf)

# %%
# Distance of each Movie with Each Movie so shape will be n x n 
print(similarity_bow.shape)
print(similarity_tfidf.shape)
# Out:
# (144, 144)
# (144, 144)

# %%
# How to not loose index while sorting
# Call the enumerate Function
print(sorted(list(enumerate(similarity_bow[0])),reverse=True,key=lambda x:x[1])[1:11])
print(sorted(list(enumerate(similarity_tfidf[0])),reverse=True,key=lambda x:x[1])[1:11])
# Out:
# [(12, 0.443321217653404), (120, 0.3970944910273665), (17, 0.373033005006058), (76, 0.3675268579217754), (22, 0.35740628145360864), (105, 0.3547775623344589), (100, 0.3104775886251114), (94, 0.3047169490613172), (111, 0.26798370867210486), (109, 0.2663635235216769)]
# [(105, 0.2149261017599347), (12, 0.2081727206764023), (120, 0.20763352551372805), (76, 0.17917433712428002), (17, 0.1776268215291792), (22, 0.16696169788507095), (8, 0.1452615796724767), (100, 0.1432740132031561), (95, 0.13995264353073575), (43, 0.13104873013103568)]

# %%
def recommend(user):
    # Fetch the Index from the Similarity Array
    # Then sort the distances in descending order of that index and return the top10 
    # They will be the most similar movies to the  given Movie
    user_index=sna[sna['user']==user].index[0]
    distances_bow=similarity_bow[user_index]
    distances_tfidf=similarity_tfidf[user_index]
    users_list_bow=sorted(list(enumerate(distances_bow)),reverse=True,key=lambda x:x[1])[1:11]
    users_list_tfidf=sorted(list(enumerate(distances_tfidf)),reverse=True,key=lambda x:x[1])[1:11]
    print("Users recommended by Bag of Words Method")
    for i in users_list_bow:
        
        #print(i[0])
        print(sna.iloc[i[0]].user)
    print("Users recommended by TF-IDF")
    for i in users_list_tfidf:
        
        #print(i[0])
        print(sna.iloc[i[0]].user)

# %%
recommend('ShaykhullinSergey')
# Out:
# Users recommended by Bag of Words Method
# Foram Shah
# Dhruvil Dave
# Simone Paolucci
# Aayush Chodvadiya
# Harshil Mehta
# Vidish Joshi
# Kairav Pithadia
# ai123456
# Harshiv Patel
# Prathamesh Shanbhag
# Users recommended by TF-IDF
# Foram Shah
# Simone Paolucci
# Aayush Chodvadiya
# Dhruvil Dave
# ai123456
# Harshil Mehta
# Vaidhyanathan S M
# Kairav Pithadia
# Harshiv Patel
# Prathamesh Shanbhag

# %%
# User-User -> Based on Followers List, Stargazers, Forks and Number of followers
