# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000241_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000042_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000073_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000215_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000325_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000320_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000238_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000278_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000186_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000025_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000069_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000120_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000263_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000324_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000235_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000060_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000103_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000224_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000147_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000283_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000266_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000159_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000094_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000007_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000152_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000075_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000237_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000096_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000148_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000151_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000019_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000065_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000061_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000102_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000137_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000331_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000143_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000116_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000338_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000244_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000138_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000087_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000014_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000169_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000031_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000168_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000110_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000158_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000181_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000340_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000327_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000017_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000212_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000337_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000048_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000043_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000117_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000072_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000322_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000310_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000085_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000112_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000150_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000307_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000161_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000006_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000272_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000044_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000100_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000297_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000250_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000178_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000009_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000139_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000121_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000123_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000175_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000028_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000326_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000101_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000059_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000067_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000318_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000256_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000077_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000261_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000164_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000084_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000289_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000259_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000253_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000133_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000305_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000130_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000002_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000228_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000197_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000124_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000058_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000049_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000299_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000155_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000010_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000217_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000276_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000022_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000232_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000270_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000081_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000108_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000079_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000229_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000020_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000098_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000207_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000179_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000003_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000109_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000030_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000107_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000005_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000304_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000057_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000205_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000182_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000126_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000056_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000035_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000089_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000323_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000092_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000201_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000246_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000012_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000287_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000047_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000062_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000214_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000346_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000248_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000027_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000334_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000111_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000295_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000008_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000070_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000285_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000106_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000333_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000176_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000288_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000050_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000145_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000177_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000268_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000335_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000185_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000149_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000037_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000315_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000053_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000312_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000203_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000298_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000021_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000242_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000167_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000329_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000078_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000343_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000275_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000293_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000219_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000129_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000313_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000352_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000095_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000273_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000213_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000339_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000032_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000026_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000321_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000292_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000068_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000330_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000274_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000225_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000156_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000173_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000000_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000132_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000013_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000086_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000131_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000001_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000302_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000184_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000317_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000174_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000328_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000091_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000016_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000064_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000350_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000136_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000220_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000051_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000004_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000163_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000180_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000342_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000306_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000344_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000105_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000183_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000332_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000119_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000088_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000341_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000196_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000216_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000036_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000254_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000247_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000018_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000165_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000066_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000034_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000269_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000135_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000264_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000041_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000029_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000039_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000199_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000271_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000188_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000157_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000023_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000336_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000024_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000223_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000347_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000125_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000097_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000099_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000115_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000260_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000294_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000348_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000140_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000198_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000257_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000122_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000054_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000200_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000076_resized.png
# /kaggle/input/themassiveindianfooddataset/Paneer-Tikka-resized/00000226_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000055_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000480_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000042_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000073_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000279_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000320_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000278_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000025_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000494_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000193_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000265_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000120_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000445_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000522_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000263_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000060_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000103_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000284_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000451_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000147_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000471_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000463_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000283_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000399_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000266_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000052_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000159_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000423_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000007_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000152_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000074_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000075_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000237_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000096_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000148_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000151_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000019_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000146_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000061_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000537_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000363_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000102_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000416_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000358_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000137_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000331_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000391_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000144_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000116_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000491_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000244_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000087_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000426_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000110_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000181_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000327_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000113_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000418_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000017_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000212_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000377_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000381_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000337_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000048_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000043_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000417_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000117_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000072_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000045_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000310_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000085_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000033_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000112_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000150_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000161_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000006_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000511_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000142_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000370_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000272_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000100_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000297_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000373_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000401_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000250_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000178_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000371_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000009_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000345_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000139_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000353_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000425_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000175_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000351_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000450_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000554_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000415_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000028_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000101_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000059_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000438_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000311_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000262_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000396_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000077_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000513_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000355_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000090_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000084_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000289_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000015_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000446_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000252_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000130_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000002_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000228_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000128_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000197_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000500_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000058_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000104_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000049_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000155_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000010_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000154_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000384_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000397_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000080_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000512_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000436_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000079_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000229_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000020_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000063_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000424_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000098_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000362_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000308_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000003_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000109_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000030_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000005_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000400_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000218_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000211_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000354_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000057_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000182_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000126_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000056_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000035_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000378_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000089_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000420_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000171_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000499_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000475_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000201_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000459_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000127_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000246_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000012_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000366_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000194_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000287_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000047_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000464_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000062_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000267_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000245_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000346_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000248_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000281_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000334_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000439_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000111_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000468_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000493_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000083_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000442_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000295_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000008_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000479_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000462_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000395_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000285_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000106_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000011_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000495_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000050_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000402_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000177_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000268_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000185_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000037_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000315_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000053_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000290_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000258_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000021_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000553_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000167_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000486_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000293_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000219_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000129_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000313_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000352_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000273_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000339_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000032_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000026_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000068_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000390_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000443_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000534_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000330_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000357_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000156_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000379_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000282_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000000_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000132_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000013_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000086_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000538_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000001_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000184_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000317_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000328_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000091_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000064_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000136_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000452_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000051_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000004_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000163_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000180_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000342_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000387_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000344_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000105_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000183_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000332_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000231_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000209_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000119_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000088_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000196_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000036_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000303_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000254_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000247_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000018_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000165_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000066_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000034_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000162_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000498_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000454_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000114_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000093_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000361_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000251_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000135_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000264_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000041_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000029_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000514_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000039_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000368_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000517_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000271_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000188_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000038_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000230_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000388_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000413_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000023_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000227_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000336_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000389_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000473_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000210_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000483_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000407_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000481_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000097_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000099_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000240_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000260_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000294_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000280_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000348_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000141_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000140_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000198_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000257_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000054_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000200_resized.png
# /kaggle/input/themassiveindianfooddataset/Pav-Bhaji-Resized/00000076_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000055_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000480_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000372_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000241_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000206_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000042_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000073_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000461_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000279_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000325_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000320_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000238_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000278_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000186_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000520_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000025_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000069_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000193_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000445_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000160_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000522_resized.png
# ...
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000022_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000232_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000270_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000080_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000081_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000286_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000108_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000431_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000457_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000079_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000229_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000020_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000063_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000424_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000098_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000207_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000179_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000308_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000003_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000030_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000380_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000508_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000107_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000005_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000400_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000218_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000211_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000304_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000354_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000057_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000182_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000126_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000056_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000404_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000035_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000089_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000191_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000369_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000171_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000201_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000405_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000246_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000012_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000194_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000287_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000040_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000047_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000464_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000525_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000062_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000202_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000346_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000248_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000071_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000027_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000334_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000439_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000468_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000493_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000008_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000070_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000462_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000285_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000386_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000106_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000011_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000176_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000288_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000050_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000314_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000177_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000335_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000185_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000037_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000315_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000053_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000082_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000432_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000234_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000203_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000190_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000298_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000526_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000290_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000021_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000242_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000329_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000078_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000486_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000275_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000465_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000219_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000129_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000213_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000032_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000026_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000292_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000068_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000443_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000330_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000274_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000357_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000510_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000166_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000156_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000519_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000379_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000173_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000000_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000132_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000013_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000086_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000131_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000001_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000184_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000317_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000489_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000174_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000382_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000016_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000064_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000350_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000220_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000367_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000051_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000316_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000383_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000430_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000482_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000004_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000163_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000180_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000387_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000306_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000344_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000105_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000183_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000233_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000332_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000365_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000209_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000509_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000088_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000192_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000196_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000303_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000254_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000247_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000018_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000165_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000162_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000498_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000114_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000093_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000135_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000041_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000029_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000514_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000039_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000517_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000199_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000188_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000038_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000230_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000157_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000458_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000388_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000413_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000398_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000336_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000024_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000389_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000210_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000481_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000099_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000240_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000046_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000260_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000141_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000140_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000198_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000187_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000319_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000122_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000054_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000200_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000460_resized.png
# /kaggle/input/themassiveindianfooddataset/Chole-Bhature-Resized/00000414_resized.png

# %%
# The data in comparison to the Original Data has been reduced to 10%
# This clearly means that there is substantially less training data and the
import os
for dirpath,dirnames,filenames in os.walk("10_food_classes_10_percent"):
    print(f"There are {len(dirnames)} Directories and {len(filenames)} Files in '{dirpath}'")

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# Setting up Global Variables for better Re-usability
IMAGE_SHAPE=(224,224)
BATCH_SIZE=32
train_dir="../input/themassiveindianfooddataset/"
train_data_generator=ImageDataGenerator(rescale=1/255.)
# test_data_generator=ImageDataGenerator(rescale=1/255.)
train_data=train_data_generator.flow_from_directory(train_dir,target_size=IMAGE_SHAPE,batch_size=BATCH_SIZE,class_mode="categorical")
# Out:
# Found 886 images belonging to 3 classes.

# %%
# Function as we need to modularize it to be reusable for all the
# Also we will be saving them to the log_dir for all the Different models we built
import datetime
def create_tensorboard_callback(dir_name, experiment_name):
  log_dir = dir_name + "/" + experiment_name + "/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
  tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir)
  print(f"Saving TensorBoard log files to: {log_dir}")
  return tensorboard_callback

# %%
train_data

# %%
import tensorflow as tf
import tensorflow_hub as hub
from tensorflow.keras import layers

# %%
# Resnet 50 V2 feature vector
resnet_url = "https://tfhub.dev/google/imagenet/resnet_v2_50/feature_vector/4"

# New: EfficientNetB0 feature vector (version 2)
efficientnet_url = "https://tfhub.dev/google/imagenet/efficientnet_v2_imagenet1k_b0/feature_vector/2"

# %%
# Function to Create a Model from an Input url
# 3 Classes as this starter Notebook is made on the Initial Dataset
def create_model(model_url, num_classes=3):
  # Download the pretrained model and save it as a Keras layer
  feature_extractor_layer = hub.KerasLayer(model_url,
                                           # freeze the underlying patterns
                                           trainable=False, 
                                           name='feature_extraction_layer',
                                           # define the input image shape
                                           input_shape=IMAGE_SHAPE+(3,)) 
  
  # Create our own model using the feature extraction layer as the base
  model = tf.keras.Sequential([
    feature_extractor_layer, 
    layers.Dense(num_classes, activation='softmax', name='output_layer') # create our own output layer      
  ])

  return model

# %%
# Create model
resnet_model = create_model(resnet_url, num_classes=train_data.num_classes)

# Compile
resnet_model.compile(loss='categorical_crossentropy',
                     optimizer=tf.keras.optimizers.Adam(),
                     metrics=['accuracy'])
# Out:
# User settings:
#
#    KMP_AFFINITY=granularity=fine,verbose,compact,1,0
#    KMP_BLOCKTIME=0
#    KMP_SETTINGS=1
#    KMP_WARNINGS=0
#
# Effective settings:
#
#    KMP_ABORT_DELAY=0
#    KMP_ADAPTIVE_LOCK_PROPS='1,1024'
#    KMP_ALIGN_ALLOC=64
#    KMP_ALL_THREADPRIVATE=128
#    KMP_ATOMIC_MODE=2
#    KMP_BLOCKTIME=0
#    KMP_CPUINFO_FILE: value is not defined
#    KMP_DETERMINISTIC_REDUCTION=false
#    KMP_DEVICE_THREAD_LIMIT=2147483647
#    KMP_DISP_NUM_BUFFERS=7
#    KMP_DUPLICATE_LIB_OK=false
#    KMP_ENABLE_TASK_THROTTLING=true
#    KMP_FORCE_REDUCTION: value is not defined
#    KMP_FOREIGN_THREADS_THREADPRIVATE=true
#    KMP_FORKJOIN_BARRIER='2,2'
#    KMP_FORKJOIN_BARRIER_PATTERN='hyper,hyper'
#    KMP_GTID_MODE=3
#    KMP_HANDLE_SIGNALS=false
#    KMP_HOT_TEAMS_MAX_LEVEL=1
#    KMP_HOT_TEAMS_MODE=0
#    KMP_INIT_AT_FORK=true
#    KMP_LIBRARY=throughput
#    KMP_LOCK_KIND=queuing
#    KMP_MALLOC_POOL_INCR=1M
#    KMP_NUM_LOCKS_IN_BLOCK=1
#    KMP_PLAIN_BARRIER='2,2'
#    KMP_PLAIN_BARRIER_PATTERN='hyper,hyper'
#    KMP_REDUCTION_BARRIER='1,1'
#    KMP_REDUCTION_BARRIER_PATTERN='hyper,hyper'
#    KMP_SCHEDULE='static,balanced;guided,iterative'
#    KMP_SETTINGS=true
#    KMP_SPIN_BACKOFF_PARAMS='4096,100'
#    KMP_STACKOFFSET=64
#    KMP_STACKPAD=0
#    KMP_STACKSIZE=8M
#    KMP_STORAGE_MAP=false
#    KMP_TASKING=2
#    KMP_TASKLOOP_MIN_TASKS=0
#    KMP_TASK_STEALING_CONSTRAINT=1
#    KMP_TEAMS_THREAD_LIMIT=4
#    KMP_TOPOLOGY_METHOD=all
#    KMP_USE_YIELD=1
#    KMP_VERSION=false
#    KMP_WARNINGS=false
#    OMP_AFFINITY_FORMAT='OMP: pid %P tid %i thread %n bound to OS proc set {%A}'
#    OMP_ALLOCATOR=omp_default_mem_alloc
#    OMP_CANCELLATION=false
#    OMP_DEFAULT_DEVICE=0
#    OMP_DISPLAY_AFFINITY=false
#    OMP_DISPLAY_ENV=false
#    OMP_DYNAMIC=false
#    OMP_MAX_ACTIVE_LEVELS=1
#    OMP_MAX_TASK_PRIORITY=0
#    OMP_NESTED: deprecated; max-active-levels-var=1
#    OMP_NUM_THREADS: value is not defined
#    OMP_PLACES: value is not defined
#    OMP_PROC_BIND='intel'
#    OMP_SCHEDULE='static'
#    OMP_STACKSIZE=8M
#    OMP_TARGET_OFFLOAD=DEFAULT
#    OMP_THREAD_LIMIT=2147483647
#    OMP_WAIT_POLICY=PASSIVE
#    KMP_AFFINITY='verbose,warnings,respect,granularity=fine,compact,1,0'
#
# 2022-01-23 08:48:38.263789: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.

# %%
# Fitting the model
resnet_history = resnet_model.fit(train_data,
                                  epochs=6,
                                  steps_per_epoch=len(train_data),
                                  # Add TensorBoard callback to model (callbacks parameter takes a list)
                                  # save experiment logs here
                                  callbacks=[create_tensorboard_callback(dir_name="tensorflow_hub", 
                                                                         # name of log files
                                                                         experiment_name="resnet50V2")])
# Out:
# 2022-01-23 08:48:40.911804: I tensorflow/core/profiler/lib/profiler_session.cc:131] Profiler session initializing.
# 2022-01-23 08:48:40.911987: I tensorflow/core/profiler/lib/profiler_session.cc:146] Profiler session started.
# 2022-01-23 08:48:40.913236: I tensorflow/core/profiler/lib/profiler_session.cc:164] Profiler session tear down.
# Saving TensorBoard log files to: tensorflow_hub/resnet50V2/20220123-084840
# 2022-01-23 08:48:41.452013: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/6
#  1/28 [>.............................] - ETA: 3:03 - loss: 1.4920 - accuracy: 0.2188
# 2022-01-23 08:48:48.682030: I tensorflow/core/profiler/lib/profiler_session.cc:131] Profiler session initializing.
# 2022-01-23 08:48:48.682227: I tensorflow/core/profiler/lib/profiler_session.cc:146] Profiler session started.
#  2/28 [=>............................] - ETA: 1:05 - loss: 1.3740 - accuracy: 0.2656
# 2022-01-23 08:48:50.792704: I tensorflow/core/profiler/lib/profiler_session.cc:66] Profiler session collecting data.
# 2022-01-23 08:48:50.804644: I tensorflow/core/profiler/lib/profiler_session.cc:164] Profiler session tear down.
# 2022-01-23 08:48:50.818971: I tensorflow/core/profiler/rpc/client/save_profile.cc:136] Creating directory: tensorflow_hub/resnet50V2/20220123-084840/train/plugins/profile/2022_01_23_08_48_50
#
# 2022-01-23 08:48:50.822498: I tensorflow/core/profiler/rpc/client/save_profile.cc:142] Dumped gzipped tool data for trace.json.gz to tensorflow_hub/resnet50V2/20220123-084840/train/plugins/profile/2022_01_23_08_48_50/b5610f48dd81.trace.json.gz
# 2022-01-23 08:48:50.849029: I tensorflow/core/profiler/rpc/client/save_profile.cc:136] Creating directory: tensorflow_hub/resnet50V2/20220123-084840/train/plugins/profile/2022_01_23_08_48_50
#
# 2022-01-23 08:48:50.851526: I tensorflow/core/profiler/rpc/client/save_profile.cc:142] Dumped gzipped tool data for memory_profile.json.gz to tensorflow_hub/resnet50V2/20220123-084840/train/plugins/profile/2022_01_23_08_48_50/b5610f48dd81.memory_profile.json.gz
# 2022-01-23 08:48:50.852545: I tensorflow/core/profiler/rpc/client/capture_profile.cc:251] Creating directory: tensorflow_hub/resnet50V2/20220123-084840/train/plugins/profile/2022_01_23_08_48_50
# Dumped tool data for xplane.pb to tensorflow_hub/resnet50V2/20220123-084840/train/plugins/profile/2022_01_23_08_48_50/b5610f48dd81.xplane.pb
# Dumped tool data for overview_page.pb to tensorflow_hub/resnet50V2/20220123-084840/train/plugins/profile/2022_01_23_08_48_50/b5610f48dd81.overview_page.pb
# Dumped tool data for input_pipeline.pb to tensorflow_hub/resnet50V2/20220123-084840/train/plugins/profile/2022_01_23_08_48_50/b5610f48dd81.input_pipeline.pb
# Dumped tool data for tensorflow_stats.pb to tensorflow_hub/resnet50V2/20220123-084840/train/plugins/profile/2022_01_23_08_48_50/b5610f48dd81.tensorflow_stats.pb
# Dumped tool data for kernel_stats.pb to tensorflow_hub/resnet50V2/20220123-084840/train/plugins/profile/2022_01_23_08_48_50/b5610f48dd81.kernel_stats.pb
#  4/28 [===>..........................] - ETA: 52s - loss: 1.2572 - accuracy: 0.3203
# /opt/conda/lib/python3.7/site-packages/PIL/Image.py:963: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# 28/28 [==============================] - 63s 2s/step - loss: 0.7463 - accuracy: 0.6625
# Epoch 2/6
# 28/28 [==============================] - 57s 2s/step - loss: 0.3374 - accuracy: 0.8883
# Epoch 3/6
# 28/28 [==============================] - 56s 2s/step - loss: 0.2489 - accuracy: 0.9210
# Epoch 4/6
# 28/28 [==============================] - 56s 2s/step - loss: 0.2018 - accuracy: 0.9424
# Epoch 5/6
# 28/28 [==============================] - 56s 2s/step - loss: 0.1664 - accuracy: 0.9605
# Epoch 6/6
# 28/28 [==============================] - 57s 2s/step - loss: 0.1454 - accuracy: 0.9729

# %%
# If you wanted to, you could really turn this into a helper function to load in with a helper.py script...
import matplotlib.pyplot as plt

def plot_loss_curves(history):
  loss = history.history['loss']


  accuracy = history.history['accuracy']


  epochs = range(len(history.history['loss']))
  plt.figure()
  plt.plot(epochs, accuracy, label='training_accuracy')
  plt.title('Accuracy')
  plt.xlabel('Epochs')
  plt.legend();

# %%
plot_loss_curves(resnet_history)
